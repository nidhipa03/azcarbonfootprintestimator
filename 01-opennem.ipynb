# %%
import arrow
import datetime
import json
import logging
import requests
import dateutil

import pandas as pd
import numpy as np

# %%
ZONE_KEY_TO_REGION = {
    'AUS-NSW': 'NSW1',
    'AUS-QLD': 'QLD1',
    'AUS-SA': 'SA1',
    'AUS-TAS': 'TAS1',
    'AUS-VIC': 'VIC1',
    'AUS-WA': 'WEM',
}
ZONE_KEY_TO_NETWORK = {
    'AUS-NSW': 'NEM',
    'AUS-QLD': 'NEM',
    'AUS-SA': 'NEM',
    'AUS-TAS': 'NEM',
    'AUS-VIC': 'NEM',
    'AUS-WA': 'WEM',
}
EXCHANGE_MAPPING_DICTIONARY = {
    'AUS-NSW->AUS-QLD': {
        'region_id': 'NSW1->QLD1',
        'direction': 1,
    },
    'AUS-NSW->AUS-VIC': {
        'region_id': 'NSW1->VIC1',
        'direction': 1,
    },
    'AUS-SA->AUS-VIC': {
        'region_id': 'SA1->VIC1',
        'direction': 1,
    },
    'AUS-TAS->AUS-VIC': {
        'region_id': 'TAS1->VIC1',
        'direction': 1,
    },
}
OPENNEM_PRODUCTION_CATEGORIES = {
    'coal': ['COAL_BLACK', 'COAL_BROWN'],
    'gas': ['GAS_CCGT', 'GAS_OCGT', 'GAS_RECIP', 'GAS_STEAM'],
    'oil': ['DISTILLATE'],
    'hydro': ['HYDRO'],
    'wind': ['WIND'],
    'biomass': ['BIOENERGY_BIOGAS', 'BIOENERGY_BIOMASS'],
    'solar': ['SOLAR_UTILITY', 'SOLAR_ROOFTOP'],
}
OPENNEM_STORAGE_CATEGORIES = {
    # Storage
    'battery': ['BATTERY_DISCHARGING', 'BATTERY_CHARGING'],
    'hydro': ['PUMPS'],
}
SOURCE = 'opennem.org.au'

# %%
def dataset_to_df(dataset):
    series = dataset['history']
    interval = series['interval']
    dt_start = arrow.get(series['start']).datetime
    dt_end = arrow.get(series['last']).datetime
    data_type = dataset['data_type']
    _id = dataset.get('id')

    if data_type != 'power':
        name = data_type.upper()
    else:
        # When `power` is given, the multiple power sources will be given
        # we therefore set `name` to the power source
        name = _id.split(".")[-2].upper()

    # Turn into minutes
    if interval[-1] == "m":
        interval += "in"

    index = pd.date_range(start=dt_start, end=dt_end, freq=interval)
    assert len(index) == len(series['data'])
    df = pd.DataFrame(index=index, data=series['data'], columns=[name])
    return df


def generate_url(zone_key, is_flow, target_datetime, logger) -> str:
    if target_datetime:
        network = ZONE_KEY_TO_NETWORK[zone_key]
        # We will fetch since the beginning of the current month
        month = arrow.get(target_datetime).floor('month').format('YYYY-MM-DD')
        if is_flow:
            url = f'http://api.opennem.org.au/stats/flow/network/{network}?month={month}'
        else:
            region = ZONE_KEY_TO_REGION.get(zone_key)
            url = f'http://api.opennem.org.au/stats/power/network/fueltech/{network}/{region}?month={month}'
    else:
        # Contains flows and production combined
        url = f'https://data.opennem.org.au/v3/clients/em/latest.json'

    return url


def fetch_main_df(data_type, zone_key=None, sorted_zone_keys=None, session=None, target_datetime=None, logger=logging.getLogger(__name__)):
    region = ZONE_KEY_TO_REGION.get(zone_key)
    url = generate_url(
        zone_key=zone_key or sorted_zone_keys[0],
        is_flow=sorted_zone_keys is not None,
        target_datetime=target_datetime,
        logger=logger)

    # Fetches the last week of data
    logger.info(f'Requesting {url}..')
    r = (session or requests).get(url)
    r.raise_for_status()
    logger.debug('Parsing JSON..')
    datasets = r.json()['data']
    logger.debug('Filtering datasets..')
    filtered_datasets = [
        ds for ds in datasets
        if ds['type'] == data_type and (
            (zone_key and ds.get('region') == region)
            or (sorted_zone_keys and ds.get('id').split('.')[-2] == EXCHANGE_MAPPING_DICTIONARY['->'.join(sorted_zone_keys)]['region_id'])
        )
    ]
    logger.debug('Concatenating datasets..')
    df = pd.concat([dataset_to_df(ds) for ds in filtered_datasets], axis=1)

    # Sometimes we get twice the columns. In that case, only return the first one
    is_duplicated_column = df.columns.duplicated(keep='last')
    if is_duplicated_column.sum():
        logger.warning(f'Dropping columns {df.columns[is_duplicated_column]} that appear more than once')
        df = df.loc[:, is_duplicated_column]

    logger.debug('Preparing capacities..')
    if data_type == 'power' and zone_key:
        # SOLAR_ROOFTOP is only given at 30 min interval, so let's interpolate it
        if 'SOLAR_ROOFTOP' in df:
            df['SOLAR_ROOFTOP'] = df['SOLAR_ROOFTOP'].interpolate(limit=5)
        # Parse capacity data
        capacities = dict([
            (obj['id'].split('.')[-2].upper(), obj.get('x_capacity_at_present'))
            for obj in filtered_datasets if obj['region'] == region
        ])
        return df, pd.Series(capacities)
    else:
        return df


def sum_vector(pd_series, keys, transform=None):
    # Only consider keys that are in the pd_series
    filtered_keys = pd_series.index.intersection(keys)

    # Require all present keys to be non-null
    pd_series_filtered = pd_series.loc[filtered_keys]
    if filtered_keys.size and pd_series_filtered.notnull().all():
        if transform:
            return pd_series_filtered.apply(transform).sum()
        return pd_series_filtered.sum()
    else:
        return None


def fetch_production(zone_key=None, session=None, target_datetime=None, logger=logging.getLogger(__name__)):
    df, capacities = fetch_main_df('power', zone_key=zone_key, session=session, target_datetime=target_datetime, logger=logger)
    # Drop interconnectors
    df = df.drop([x for x in df.columns if '->' in x], axis=1)

    # Make sure charging is counted positively
    # and discharging negetively
    if 'BATTERY_DISCHARGING' in df.columns:
        df['BATTERY_DISCHARGING'] = df['BATTERY_DISCHARGING'] * -1

    logger.debug('Preparing final objects..')
    objs = [{
        'datetime': arrow.get(dt.to_pydatetime()).datetime,
        'production': {  # Unit is MW
            'coal': sum_vector(row, OPENNEM_PRODUCTION_CATEGORIES['coal']),
            'gas': sum_vector(row, OPENNEM_PRODUCTION_CATEGORIES['gas']),
            'oil': sum_vector(row, OPENNEM_PRODUCTION_CATEGORIES['oil']),
            'hydro': sum_vector(row, OPENNEM_PRODUCTION_CATEGORIES['hydro']),
            'wind': sum_vector(row, OPENNEM_PRODUCTION_CATEGORIES['wind']),
            'biomass': sum_vector(row, OPENNEM_PRODUCTION_CATEGORIES['biomass']),
            # We here assume all rooftop solar is fed to the grid
            # This assumption should be checked and we should here only report
            # grid-level generation
            'solar': sum_vector(row, OPENNEM_PRODUCTION_CATEGORIES['solar']),
        },
        'storage': {
            # opennem reports charging as negative, we here should report as positive
            # Note: we made the sign switch before, so we can just sum them up
            'battery': sum_vector(row, OPENNEM_STORAGE_CATEGORIES['battery']),
            # opennem reports pumping as positive, we here should report as positive
            'hydro': sum_vector(row, OPENNEM_STORAGE_CATEGORIES['hydro']),
        },
        'capacity': {
            'coal': sum_vector(capacities, OPENNEM_PRODUCTION_CATEGORIES['coal']),
            'gas': sum_vector(capacities, OPENNEM_PRODUCTION_CATEGORIES['gas']),
            'oil': sum_vector(capacities, OPENNEM_PRODUCTION_CATEGORIES['oil']),
            'hydro': sum_vector(capacities, OPENNEM_PRODUCTION_CATEGORIES['hydro']),
            'wind': sum_vector(capacities, OPENNEM_PRODUCTION_CATEGORIES['wind']),
            'biomass': sum_vector(capacities, OPENNEM_PRODUCTION_CATEGORIES['biomass']),
            'solar': sum_vector(capacities, OPENNEM_PRODUCTION_CATEGORIES['solar']),
            'hydro storage': capacities.get(OPENNEM_STORAGE_CATEGORIES['hydro'][0]),
            'battery storage': capacities.get(OPENNEM_STORAGE_CATEGORIES['battery'][0]),
        },
        'source': SOURCE,
        'zoneKey': zone_key,
    } for dt, row in df.iterrows()]

    # Validation
    logger.debug('Validating..')
    for obj in objs:
        for k, v in obj['production'].items():
            if v is None:
                continue
            if v < 0 and v > -50:
                # Set small negative values to 0
                logger.warning(f'Setting small value of {k} ({v}) to 0.',
                               extra={'key': zone_key})
                obj['production'][k] = 0

    return objs


def fetch_price(zone_key=None, session=None, target_datetime=None, logger=logging.getLogger(__name__)) -> list:
    df = fetch_main_df('price', zone_key=zone_key, session=session, target_datetime=target_datetime, logger=logger)
    df = df.loc[~df['PRICE'].isna()]  # Only keep prices that are defined
    return [{
        'datetime': arrow.get(dt.to_pydatetime()).datetime,
        'price': sum_vector(row, ['PRICE']),  # currency / MWh
        'currency': 'AUD',
        'source': SOURCE,
        'zoneKey': zone_key,
    } for dt, row in df.iterrows()]


def fetch_exchange(zone_key1, zone_key2, session=None, target_datetime=None, logger=logging.getLogger(__name__)) -> list:
    sorted_zone_keys = sorted([zone_key1, zone_key2])
    key = '->'.join(sorted_zone_keys)
    df = fetch_main_df('power', sorted_zone_keys=sorted_zone_keys, session=session, target_datetime=target_datetime, logger=logger)
    direction = EXCHANGE_MAPPING_DICTIONARY[key]['direction']

    # Take the first column (there's only one)
    series = df.iloc[:, 0]

    return [{
        'datetime': arrow.get(dt.to_pydatetime()).datetime,
        'netFlow': value * direction,
        'source': SOURCE,
        'sortedZoneKeys': key,
    } for dt, value in series.iteritems()]

# %%
datetime=datetime.datetime(2021, 10, 12, 9, 15, tzinfo=dateutil.tz.tzoffset(None, 36000))

# %%
result = fetch_production('AUS-NSW', target_datetime=datetime)
# Out:
# Setting small value of oil (-0.07589) to 0.
# Setting small value of oil (-0.07589) to 0.
# Setting small value of oil (-0.07589) to 0.
# Setting small value of oil (-0.07589) to 0.
# Setting small value of oil (-0.07589) to 0.
# Setting small value of oil (-0.07589) to 0.
# Setting small value of oil (-0.07589) to 0.
# Setting small value of oil (-0.07589) to 0.
# Setting small value of oil (-0.0728) to 0.
# Setting small value of oil (-0.0728) to 0.
# Setting small value of oil (-0.0728) to 0.
# Setting small value of oil (-0.0728) to 0.
# Setting small value of oil (-0.0728) to 0.
# Setting small value of oil (-0.0728) to 0.
# Setting small value of oil (-0.0728) to 0.
# Setting small value of oil (-0.0728) to 0.
# Setting small value of oil (-0.0728) to 0.
# Setting small value of oil (-0.07521) to 0.
# Setting small value of oil (-0.07521) to 0.
# Setting small value of oil (-0.07521) to 0.
# Setting small value of oil (-0.07521) to 0.
# Setting small value of oil (-0.07521) to 0.
# Setting small value of oil (-0.07521) to 0.
# Setting small value of oil (-0.07521) to 0.
# Setting small value of oil (-0.07521) to 0.
# Setting small value of oil (-0.07521) to 0.
# Setting small value of oil (-0.07712) to 0.
# Setting small value of oil (-0.07712) to 0.
# Setting small value of oil (-0.07712) to 0.
# Setting small value of oil (-0.07712) to 0.
# Setting small value of oil (-0.07712) to 0.
# Setting small value of oil (-0.07712) to 0.
# Setting small value of oil (-0.07712) to 0.
# Setting small value of oil (-0.07712) to 0.
# Setting small value of oil (-0.07712) to 0.
# Setting small value of oil (-0.07757) to 0.
# Setting small value of oil (-0.07757) to 0.
# Setting small value of oil (-0.07757) to 0.
# Setting small value of oil (-0.07757) to 0.
# Setting small value of oil (-0.07757) to 0.
# Setting small value of oil (-0.07757) to 0.
# Setting small value of oil (-0.07757) to 0.
# Setting small value of oil (-0.07757) to 0.
# Setting small value of oil (-0.07757) to 0.
# Setting small value of oil (-0.07679) to 0.
# Setting small value of oil (-0.07679) to 0.
# Setting small value of oil (-0.07679) to 0.
# Setting small value of oil (-0.07679) to 0.
# Setting small value of oil (-0.07679) to 0.
# Setting small value of oil (-0.07679) to 0.
# Setting small value of oil (-0.07679) to 0.
# Setting small value of oil (-0.07679) to 0.
# Setting small value of oil (-0.07679) to 0.
# Setting small value of oil (-0.07721) to 0.
# Setting small value of oil (-0.07721) to 0.
# Setting small value of oil (-0.07721) to 0.
# Setting small value of oil (-0.07721) to 0.
# Setting small value of oil (-0.07721) to 0.
# Setting small value of oil (-0.07721) to 0.
# Setting small value of oil (-0.07721) to 0.
# Setting small value of oil (-0.07721) to 0.
# Setting small value of oil (-0.07721) to 0.
# Setting small value of oil (-0.07629) to 0.
# Setting small value of oil (-0.07629) to 0.
# Setting small value of oil (-0.07629) to 0.
# Setting small value of oil (-0.07629) to 0.
# Setting small value of oil (-0.07629) to 0.
# Setting small value of oil (-0.07629) to 0.
# Setting small value of oil (-0.07629) to 0.
# Setting small value of oil (-0.07629) to 0.
# Setting small value of oil (-0.07629) to 0.
# Setting small value of oil (-0.07305) to 0.
# Setting small value of oil (-0.07305) to 0.
# Setting small value of oil (-0.07305) to 0.
# Setting small value of oil (-0.07305) to 0.
# Setting small value of oil (-0.07305) to 0.
# Setting small value of oil (-0.07305) to 0.
# Setting small value of oil (-0.07305) to 0.
# Setting small value of oil (-0.07305) to 0.
# Setting small value of oil (-0.07305) to 0.
# Setting small value of oil (-0.07449) to 0.
# Setting small value of oil (-0.07449) to 0.
# Setting small value of oil (-0.07449) to 0.
# Setting small value of oil (-0.07449) to 0.
# Setting small value of oil (-0.07449) to 0.
# Setting small value of oil (-0.07449) to 0.
# Setting small value of oil (-0.07449) to 0.
# Setting small value of oil (-0.07449) to 0.
# Setting small value of oil (-0.07449) to 0.
# Setting small value of oil (-0.0757) to 0.
# Setting small value of oil (-0.0757) to 0.
# Setting small value of oil (-0.0757) to 0.
# Setting small value of oil (-0.0757) to 0.
# Setting small value of oil (-0.0757) to 0.
# Setting small value of oil (-0.0757) to 0.
# Setting small value of oil (-0.0757) to 0.
# Setting small value of oil (-0.0757) to 0.
# Setting small value of oil (-0.0757) to 0.
# Setting small value of oil (-0.07289) to 0.
# Setting small value of oil (-0.07289) to 0.
# Setting small value of oil (-0.07289) to 0.
# Setting small value of oil (-0.07289) to 0.
# Setting small value of oil (-0.07289) to 0.
# Setting small value of oil (-0.07289) to 0.
# Setting small value of oil (-0.07289) to 0.
# Setting small value of oil (-0.07289) to 0.
# Setting small value of oil (-0.07289) to 0.
# Setting small value of oil (-0.06973) to 0.
# Setting small value of oil (-0.06973) to 0.
# Setting small value of oil (-0.06973) to 0.
# Setting small value of oil (-0.06973) to 0.
# Setting small value of oil (-0.06973) to 0.
# Setting small value of oil (-0.06973) to 0.
# Setting small value of oil (-0.06973) to 0.
# Setting small value of oil (-0.06973) to 0.
# Setting small value of oil (-0.06973) to 0.
# Setting small value of oil (-0.07408) to 0.
# Setting small value of oil (-0.07408) to 0.
# Setting small value of oil (-0.07408) to 0.
# Setting small value of oil (-0.07408) to 0.
# Setting small value of oil (-0.07408) to 0.
# Setting small value of oil (-0.07408) to 0.
# Setting small value of oil (-0.07408) to 0.
# Setting small value of oil (-0.07408) to 0.
# Setting small value of oil (-0.07408) to 0.
# Setting small value of oil (-0.08021) to 0.
# Setting small value of oil (-0.08021) to 0.
# Setting small value of oil (-0.08021) to 0.
# Setting small value of oil (-0.08021) to 0.
# Setting small value of oil (-0.08021) to 0.
# Setting small value of oil (-0.08021) to 0.
# Setting small value of oil (-0.08021) to 0.
# Setting small value of oil (-0.08021) to 0.
# Setting small value of oil (-0.08021) to 0.
# Setting small value of oil (-0.07968) to 0.
# Setting small value of oil (-0.07968) to 0.
# Setting small value of oil (-0.07968) to 0.
# Setting small value of oil (-0.07968) to 0.
# Setting small value of oil (-0.07968) to 0.
# Setting small value of oil (-0.07968) to 0.
# Setting small value of oil (-0.07968) to 0.
# Setting small value of oil (-0.07968) to 0.
# Setting small value of oil (-0.07968) to 0.
# Setting small value of oil (-0.08472) to 0.
# Setting small value of oil (-0.08472) to 0.
# Setting small value of oil (-0.08472) to 0.
# Setting small value of oil (-0.08472) to 0.
# Setting small value of oil (-0.08472) to 0.
# Setting small value of oil (-0.08472) to 0.
# Setting small value of oil (-0.08472) to 0.
# Setting small value of oil (-0.08472) to 0.
# Setting small value of oil (-0.08472) to 0.
# Setting small value of oil (-0.08328) to 0.
# Setting small value of oil (-0.08328) to 0.
# Setting small value of oil (-0.08328) to 0.
# Setting small value of oil (-0.08328) to 0.
# Setting small value of oil (-0.08328) to 0.
# Setting small value of oil (-0.08328) to 0.
# Setting small value of oil (-0.08328) to 0.
# Setting small value of oil (-0.08328) to 0.
# Setting small value of oil (-0.08328) to 0.
# Setting small value of oil (-0.08519) to 0.
# Setting small value of oil (-0.08519) to 0.
# Setting small value of oil (-0.08519) to 0.
# Setting small value of oil (-0.08519) to 0.
# Setting small value of oil (-0.08519) to 0.
# Setting small value of oil (-0.08519) to 0.
# Setting small value of oil (-0.08519) to 0.
# Setting small value of oil (-0.08519) to 0.
# Setting small value of oil (-0.08519) to 0.
# Setting small value of oil (-0.08379) to 0.
# Setting small value of oil (-0.08379) to 0.
# Setting small value of oil (-0.08379) to 0.
# Setting small value of oil (-0.08379) to 0.
# Setting small value of oil (-0.08379) to 0.
# Setting small value of oil (-0.08379) to 0.
# Setting small value of oil (-0.08379) to 0.
# Setting small value of oil (-0.08379) to 0.
# Setting small value of oil (-0.08379) to 0.
# Setting small value of oil (-0.07935) to 0.
# Setting small value of oil (-0.07935) to 0.
# Setting small value of oil (-0.07935) to 0.
# Setting small value of oil (-0.07935) to 0.
# Setting small value of oil (-0.07935) to 0.
# Setting small value of oil (-0.07935) to 0.
# Setting small value of oil (-0.07935) to 0.
# Setting small value of oil (-0.07935) to 0.
# Setting small value of oil (-0.07935) to 0.
# Setting small value of oil (-0.07812) to 0.
# Setting small value of oil (-0.07812) to 0.
# Setting small value of oil (-0.07812) to 0.
# Setting small value of oil (-0.07812) to 0.
# Setting small value of oil (-0.07812) to 0.
# Setting small value of oil (-0.07812) to 0.
# Setting small value of oil (-0.07812) to 0.
# Setting small value of oil (-0.07812) to 0.
# Setting small value of oil (-0.07812) to 0.
# Setting small value of oil (-0.08157) to 0.
# Setting small value of oil (-0.08157) to 0.
# Setting small value of oil (-0.08157) to 0.
# Setting small value of oil (-0.08157) to 0.
# Setting small value of oil (-0.08157) to 0.
# Setting small value of oil (-0.08157) to 0.
# Setting small value of oil (-0.08157) to 0.
# Setting small value of oil (-0.08157) to 0.
# Setting small value of oil (-0.08157) to 0.
# Setting small value of oil (-0.076) to 0.
# Setting small value of oil (-0.076) to 0.
# Setting small value of oil (-0.076) to 0.
# Setting small value of oil (-0.076) to 0.
# Setting small value of oil (-0.076) to 0.
# Setting small value of oil (-0.076) to 0.
# Setting small value of oil (-0.076) to 0.
# Setting small value of oil (-0.076) to 0.
# Setting small value of oil (-0.076) to 0.
# Setting small value of oil (-0.07809) to 0.
# Setting small value of oil (-0.07809) to 0.
# Setting small value of oil (-0.07809) to 0.
# Setting small value of oil (-0.07809) to 0.
# Setting small value of oil (-0.07809) to 0.
# Setting small value of oil (-0.07809) to 0.
# Setting small value of oil (-0.07809) to 0.
# Setting small value of oil (-0.07809) to 0.
# Setting small value of oil (-0.07809) to 0.
# Setting small value of oil (-0.07933) to 0.
# Setting small value of oil (-0.07933) to 0.
# Setting small value of oil (-0.07933) to 0.
# Setting small value of oil (-0.07933) to 0.
# Setting small value of oil (-0.07933) to 0.
# Setting small value of oil (-0.07933) to 0.
# Setting small value of oil (-0.07933) to 0.
# Setting small value of oil (-0.07933) to 0.
# Setting small value of oil (-0.07933) to 0.
# Setting small value of oil (-0.07703) to 0.
# Setting small value of oil (-0.07703) to 0.
# Setting small value of oil (-0.07703) to 0.
# Setting small value of oil (-0.07703) to 0.
# Setting small value of oil (-0.07703) to 0.
# Setting small value of oil (-0.07703) to 0.
# Setting small value of oil (-0.07703) to 0.
# Setting small value of oil (-0.07822) to 0.
# Setting small value of oil (-0.07822) to 0.
# Setting small value of oil (-0.07736) to 0.
# Setting small value of oil (-0.07736) to 0.
# Setting small value of oil (-0.07736) to 0.
# Setting small value of oil (-0.07736) to 0.
# Setting small value of oil (-0.07736) to 0.
# Setting small value of oil (-0.07736) to 0.
# Setting small value of oil (-0.07736) to 0.
# Setting small value of oil (-0.07736) to 0.
# Setting small value of oil (-0.07736) to 0.
# Setting small value of oil (-0.0767) to 0.
# Setting small value of oil (-0.0767) to 0.
# Setting small value of oil (-0.0767) to 0.
# Setting small value of oil (-0.0767) to 0.
# Setting small value of oil (-0.0767) to 0.
# Setting small value of oil (-0.0767) to 0.
# Setting small value of oil (-0.0767) to 0.
# Setting small value of oil (-0.0767) to 0.
# Setting small value of oil (-0.0767) to 0.
# Setting small value of oil (-0.0738) to 0.
# Setting small value of oil (-0.0738) to 0.
# Setting small value of oil (-0.0738) to 0.
# Setting small value of oil (-0.0738) to 0.
# Setting small value of oil (-0.0738) to 0.
# Setting small value of oil (-0.0738) to 0.
# Setting small value of oil (-0.0738) to 0.
# Setting small value of oil (-0.0738) to 0.
# Setting small value of oil (-0.0738) to 0.
# Setting small value of oil (-0.07528) to 0.
# Setting small value of oil (-0.07528) to 0.
# Setting small value of oil (-0.07528) to 0.
# Setting small value of oil (-0.07528) to 0.
# Setting small value of oil (-0.07528) to 0.
# Setting small value of oil (-0.07528) to 0.
# Setting small value of oil (-0.07528) to 0.
# Setting small value of oil (-0.07528) to 0.
# Setting small value of oil (-0.07528) to 0.
# Setting small value of oil (-0.08048) to 0.
# Setting small value of oil (-0.08048) to 0.
# Setting small value of oil (-0.08048) to 0.
# Setting small value of oil (-0.08048) to 0.
# Setting small value of oil (-0.08048) to 0.
# Setting small value of oil (-0.08048) to 0.
# Setting small value of oil (-0.08048) to 0.
# Setting small value of oil (-0.08048) to 0.
# Setting small value of oil (-0.08048) to 0.
# Setting small value of oil (-0.07861) to 0.
# Setting small value of oil (-0.07861) to 0.
# Setting small value of oil (-0.07861) to 0.
# Setting small value of oil (-0.07861) to 0.
# Setting small value of oil (-0.07861) to 0.
# Setting small value of oil (-0.07861) to 0.
# Setting small value of oil (-0.07861) to 0.
# Setting small value of oil (-0.07861) to 0.
# Setting small value of oil (-0.07861) to 0.
# Setting small value of oil (-0.07555) to 0.
# Setting small value of oil (-0.07555) to 0.
# Setting small value of oil (-0.07555) to 0.
# Setting small value of oil (-0.07555) to 0.
# Setting small value of oil (-0.07555) to 0.
# Setting small value of oil (-0.07555) to 0.
# Setting small value of oil (-0.07555) to 0.
# Setting small value of oil (-0.07555) to 0.
# Setting small value of oil (-0.07555) to 0.
# Setting small value of oil (-0.0705) to 0.
# Setting small value of oil (-0.0705) to 0.
# Setting small value of oil (-0.0705) to 0.
# Setting small value of oil (-0.0705) to 0.
# Setting small value of oil (-0.0705) to 0.
# Setting small value of oil (-0.0705) to 0.
# Setting small value of oil (-0.0705) to 0.
# Setting small value of oil (-0.0705) to 0.
# Setting small value of oil (-0.0705) to 0.
# Setting small value of oil (-0.07389) to 0.
# Setting small value of oil (-0.07389) to 0.
# Setting small value of oil (-0.07389) to 0.
# Setting small value of oil (-0.07389) to 0.
# Setting small value of oil (-0.07389) to 0.
# Setting small value of oil (-0.07389) to 0.
# Setting small value of oil (-0.07389) to 0.
# Setting small value of oil (-0.07389) to 0.
# Setting small value of oil (-0.07389) to 0.
# Setting small value of oil (-0.0753) to 0.
# Setting small value of oil (-0.0753) to 0.
# Setting small value of oil (-0.0753) to 0.
# Setting small value of oil (-0.0753) to 0.
# Setting small value of oil (-0.0753) to 0.
# Setting small value of oil (-0.0753) to 0.
# Setting small value of oil (-0.0753) to 0.
# Setting small value of oil (-0.0753) to 0.
# Setting small value of oil (-0.0753) to 0.
# Setting small value of oil (-0.07464) to 0.
# Setting small value of oil (-0.07464) to 0.
# Setting small value of oil (-0.07464) to 0.
# Setting small value of oil (-0.07464) to 0.
# Setting small value of oil (-0.07464) to 0.
# Setting small value of oil (-0.07464) to 0.
# Setting small value of oil (-0.07464) to 0.
# Setting small value of oil (-0.07464) to 0.
# Setting small value of oil (-0.07464) to 0.
# Setting small value of oil (-0.0747) to 0.
# Setting small value of oil (-0.0747) to 0.
# Setting small value of oil (-0.0747) to 0.
# Setting small value of oil (-0.0747) to 0.
# Setting small value of oil (-0.0747) to 0.
# Setting small value of oil (-0.0747) to 0.
# Setting small value of oil (-0.0747) to 0.
# Setting small value of oil (-0.0747) to 0.
# Setting small value of oil (-0.0747) to 0.
# Setting small value of oil (-0.07779) to 0.
# Setting small value of oil (-0.07779) to 0.
# Setting small value of oil (-0.07779) to 0.
# Setting small value of oil (-0.07779) to 0.
# Setting small value of oil (-0.07779) to 0.
# Setting small value of oil (-0.07779) to 0.
# Setting small value of oil (-0.07779) to 0.
# Setting small value of oil (-0.07779) to 0.
# Setting small value of oil (-0.07779) to 0.
# Setting small value of oil (-0.07907) to 0.
# Setting small value of oil (-0.07907) to 0.
# Setting small value of oil (-0.07907) to 0.
# Setting small value of oil (-0.07907) to 0.
# Setting small value of oil (-0.07907) to 0.
# Setting small value of oil (-0.07907) to 0.
# Setting small value of oil (-0.07907) to 0.
# Setting small value of oil (-0.07907) to 0.
# Setting small value of oil (-0.07907) to 0.
# Setting small value of oil (-0.08681) to 0.
# Setting small value of oil (-0.08681) to 0.
# Setting small value of oil (-0.08681) to 0.
# Setting small value of oil (-0.08681) to 0.
# Setting small value of oil (-0.08681) to 0.
# Setting small value of oil (-0.08681) to 0.
# Setting small value of oil (-0.08681) to 0.
# Setting small value of oil (-0.08681) to 0.
# Setting small value of oil (-0.08681) to 0.
# Setting small value of oil (-0.08339) to 0.
# Setting small value of oil (-0.08339) to 0.
# Setting small value of oil (-0.08339) to 0.
# Setting small value of oil (-0.08339) to 0.
# Setting small value of oil (-0.08339) to 0.
# Setting small value of oil (-0.08339) to 0.
# Setting small value of oil (-0.08339) to 0.
# Setting small value of oil (-0.08339) to 0.
# Setting small value of oil (-0.08339) to 0.
# Setting small value of oil (-0.08387) to 0.
# Setting small value of oil (-0.08387) to 0.
# Setting small value of oil (-0.08387) to 0.
# Setting small value of oil (-0.08387) to 0.
# Setting small value of oil (-0.08387) to 0.
# Setting small value of oil (-0.08387) to 0.
# Setting small value of oil (-0.08387) to 0.
# Setting small value of oil (-0.08387) to 0.
# Setting small value of oil (-0.08387) to 0.
# Setting small value of oil (-0.08014) to 0.
# Setting small value of oil (-0.08014) to 0.
# Setting small value of oil (-0.08014) to 0.
# Setting small value of oil (-0.08014) to 0.
# Setting small value of oil (-0.08014) to 0.
# Setting small value of oil (-0.08014) to 0.
# Setting small value of oil (-0.08014) to 0.
# Setting small value of oil (-0.08014) to 0.
# Setting small value of oil (-0.08014) to 0.
# Setting small value of oil (-0.07452) to 0.
# Setting small value of oil (-0.07452) to 0.
# Setting small value of oil (-0.07452) to 0.
# Setting small value of oil (-0.07452) to 0.
# Setting small value of oil (-0.07452) to 0.
# Setting small value of oil (-0.07452) to 0.
# Setting small value of oil (-0.07452) to 0.
# Setting small value of oil (-0.07452) to 0.
# Setting small value of oil (-0.07452) to 0.
# Setting small value of oil (-0.07444) to 0.
# Setting small value of oil (-0.07444) to 0.
# Setting small value of oil (-0.07444) to 0.
# Setting small value of oil (-0.07444) to 0.
# Setting small value of oil (-0.07444) to 0.
# Setting small value of oil (-0.07444) to 0.
# Setting small value of oil (-0.07444) to 0.
# Setting small value of oil (-0.07444) to 0.
# Setting small value of oil (-0.07444) to 0.
# Setting small value of oil (-0.07325) to 0.
# Setting small value of oil (-0.07325) to 0.
# Setting small value of oil (-0.07325) to 0.
# Setting small value of oil (-0.07325) to 0.
# Setting small value of oil (-0.07325) to 0.
# Setting small value of oil (-0.07325) to 0.
# Setting small value of oil (-0.07325) to 0.
# Setting small value of oil (-0.07325) to 0.
# Setting small value of oil (-0.07325) to 0.
# Setting small value of oil (-0.07532) to 0.
# Setting small value of oil (-0.07532) to 0.
# Setting small value of oil (-0.07532) to 0.
# Setting small value of oil (-0.07532) to 0.
# Setting small value of oil (-0.07532) to 0.
# Setting small value of oil (-0.07532) to 0.
# Setting small value of oil (-0.07532) to 0.
# Setting small value of oil (-0.07532) to 0.
# Setting small value of oil (-0.07532) to 0.
# Setting small value of oil (-0.08148) to 0.
# Setting small value of oil (-0.08148) to 0.
# Setting small value of oil (-0.08148) to 0.
# Setting small value of oil (-0.08148) to 0.
# Setting small value of oil (-0.08148) to 0.
# Setting small value of oil (-0.08148) to 0.
# Setting small value of oil (-0.08148) to 0.
# Setting small value of oil (-0.08148) to 0.
# Setting small value of oil (-0.08148) to 0.
# Setting small value of oil (-0.08582) to 0.
# Setting small value of oil (-0.08582) to 0.
# Setting small value of oil (-0.08582) to 0.
# Setting small value of oil (-0.08582) to 0.
# Setting small value of oil (-0.08582) to 0.
# Setting small value of oil (-0.08582) to 0.
# Setting small value of oil (-0.08582) to 0.
# Setting small value of oil (-0.08582) to 0.
# Setting small value of oil (-0.08582) to 0.
# Setting small value of oil (-0.08165) to 0.
# Setting small value of oil (-0.08165) to 0.
# Setting small value of oil (-0.08165) to 0.
# Setting small value of oil (-0.08165) to 0.
# Setting small value of oil (-0.08165) to 0.
# Setting small value of oil (-0.08165) to 0.
# Setting small value of oil (-0.08165) to 0.
# Setting small value of oil (-0.08165) to 0.
# Setting small value of oil (-0.08165) to 0.
# Setting small value of oil (-0.08069) to 0.
# Setting small value of oil (-0.08069) to 0.
# Setting small value of oil (-0.08069) to 0.
# Setting small value of oil (-0.08069) to 0.
# Setting small value of oil (-0.08069) to 0.
# Setting small value of oil (-0.08069) to 0.
# Setting small value of oil (-0.08069) to 0.
# Setting small value of oil (-0.08069) to 0.
# Setting small value of oil (-0.08069) to 0.
# Setting small value of oil (-0.08092) to 0.
# Setting small value of oil (-0.08092) to 0.
# Setting small value of oil (-0.08092) to 0.
# Setting small value of oil (-0.08092) to 0.
# Setting small value of oil (-0.08092) to 0.
# Setting small value of oil (-0.08092) to 0.
# Setting small value of oil (-0.08092) to 0.
# Setting small value of oil (-0.08092) to 0.
# Setting small value of oil (-0.08092) to 0.
# Setting small value of oil (-0.08094) to 0.
# Setting small value of oil (-0.08094) to 0.
# Setting small value of oil (-0.08094) to 0.
# Setting small value of oil (-0.08094) to 0.
# Setting small value of oil (-0.08094) to 0.
# Setting small value of oil (-0.08094) to 0.
# Setting small value of oil (-0.08094) to 0.
# Setting small value of oil (-0.08094) to 0.
# Setting small value of oil (-0.08094) to 0.
# Setting small value of oil (-0.08362) to 0.
# Setting small value of oil (-0.08362) to 0.
# Setting small value of oil (-0.08362) to 0.
# Setting small value of oil (-0.08362) to 0.
# Setting small value of oil (-0.08362) to 0.
# Setting small value of oil (-0.08362) to 0.
# Setting small value of oil (-0.08362) to 0.
# Setting small value of oil (-0.08362) to 0.
# Setting small value of oil (-0.08362) to 0.
# Setting small value of oil (-0.07753) to 0.
# Setting small value of oil (-0.07753) to 0.
# Setting small value of oil (-0.07753) to 0.
# Setting small value of oil (-0.07753) to 0.
# Setting small value of oil (-0.07753) to 0.
# Setting small value of oil (-0.07753) to 0.
# Setting small value of oil (-0.07753) to 0.
# Setting small value of oil (-0.07753) to 0.
# Setting small value of oil (-0.07753) to 0.
# Setting small value of oil (-0.07447) to 0.
# Setting small value of oil (-0.07447) to 0.
# Setting small value of oil (-0.07447) to 0.
# Setting small value of oil (-0.07447) to 0.
# Setting small value of oil (-0.07447) to 0.
# Setting small value of oil (-0.07447) to 0.
# Setting small value of oil (-0.07447) to 0.
# Setting small value of oil (-0.07447) to 0.
# Setting small value of oil (-0.07447) to 0.
# Setting small value of oil (-0.07633) to 0.
# Setting small value of oil (-0.07633) to 0.
# Setting small value of oil (-0.07633) to 0.
# Setting small value of oil (-0.07633) to 0.
# Setting small value of oil (-0.07633) to 0.
# Setting small value of oil (-0.07633) to 0.
# Setting small value of oil (-0.07633) to 0.
# Setting small value of oil (-0.07633) to 0.
# Setting small value of oil (-0.07633) to 0.
# Setting small value of oil (-0.07354) to 0.
# Setting small value of oil (-0.07354) to 0.
# Setting small value of oil (-0.07354) to 0.
# Setting small value of oil (-0.07354) to 0.
# Setting small value of oil (-0.07354) to 0.
# Setting small value of oil (-0.07354) to 0.
# Setting small value of oil (-0.07354) to 0.
# Setting small value of oil (-0.07354) to 0.
# Setting small value of oil (-0.07354) to 0.
# Setting small value of oil (-0.06616) to 0.
# Setting small value of oil (-0.06616) to 0.
# Setting small value of oil (-0.06616) to 0.
# Setting small value of oil (-0.06616) to 0.
# Setting small value of oil (-0.06616) to 0.
# Setting small value of oil (-0.06616) to 0.
# Setting small value of oil (-0.06616) to 0.
# Setting small value of oil (-0.06616) to 0.
# Setting small value of oil (-0.06616) to 0.
# Setting small value of oil (-0.0684) to 0.
# Setting small value of oil (-0.0684) to 0.
# Setting small value of oil (-0.0684) to 0.
# Setting small value of oil (-0.0684) to 0.
# Setting small value of oil (-0.0684) to 0.
# Setting small value of oil (-0.0684) to 0.
# Setting small value of oil (-0.0684) to 0.
# Setting small value of oil (-0.0684) to 0.
# Setting small value of oil (-0.0684) to 0.
# Setting small value of oil (-0.06784) to 0.
# Setting small value of oil (-0.06784) to 0.
# Setting small value of oil (-0.06784) to 0.
# Setting small value of oil (-0.06784) to 0.
# Setting small value of oil (-0.06784) to 0.
# Setting small value of oil (-0.06784) to 0.
# Setting small value of oil (-0.06784) to 0.
# Setting small value of oil (-0.06784) to 0.
# Setting small value of oil (-0.06784) to 0.
# Setting small value of oil (-0.06836) to 0.
# Setting small value of oil (-0.06836) to 0.
# Setting small value of oil (-0.06836) to 0.
# Setting small value of oil (-0.06836) to 0.
# Setting small value of oil (-0.06836) to 0.
# Setting small value of oil (-0.06836) to 0.
# Setting small value of oil (-0.06836) to 0.
# Setting small value of oil (-0.06836) to 0.
# Setting small value of oil (-0.06836) to 0.
# Setting small value of oil (-0.07394) to 0.
# Setting small value of oil (-0.07394) to 0.
# Setting small value of oil (-0.07394) to 0.
# Setting small value of oil (-0.07394) to 0.
# Setting small value of oil (-0.07394) to 0.
# Setting small value of oil (-0.07394) to 0.
# Setting small value of oil (-0.07394) to 0.
# Setting small value of oil (-0.07394) to 0.
# Setting small value of oil (-0.07394) to 0.
# Setting small value of oil (-0.07204) to 0.
# Setting small value of oil (-0.07204) to 0.
# Setting small value of oil (-0.07204) to 0.
# Setting small value of oil (-0.07204) to 0.
# Setting small value of oil (-0.07204) to 0.
# Setting small value of oil (-0.07204) to 0.
# Setting small value of oil (-0.07204) to 0.
# Setting small value of oil (-0.07204) to 0.
# Setting small value of oil (-0.07204) to 0.
# Setting small value of oil (-0.06911) to 0.
# Setting small value of oil (-0.06911) to 0.
# Setting small value of oil (-0.06911) to 0.
# Setting small value of oil (-0.06911) to 0.
# Setting small value of oil (-0.06911) to 0.
# Setting small value of oil (-0.06911) to 0.
# Setting small value of oil (-0.06911) to 0.
# Setting small value of oil (-0.06911) to 0.
# Setting small value of oil (-0.06911) to 0.
# Setting small value of oil (-0.07405) to 0.
# Setting small value of oil (-0.07405) to 0.
# Setting small value of oil (-0.07405) to 0.
# Setting small value of oil (-0.07405) to 0.
# Setting small value of oil (-0.07405) to 0.
# Setting small value of oil (-0.07405) to 0.
# Setting small value of oil (-0.07405) to 0.
# Setting small value of oil (-0.07405) to 0.
# Setting small value of oil (-0.07405) to 0.
# Setting small value of oil (-0.07271) to 0.
# Setting small value of oil (-0.07271) to 0.
# Setting small value of oil (-0.07271) to 0.
# Setting small value of oil (-0.07271) to 0.
# Setting small value of oil (-0.07271) to 0.
# Setting small value of oil (-0.07271) to 0.
# Setting small value of oil (-0.07271) to 0.
# Setting small value of oil (-0.07271) to 0.
# Setting small value of oil (-0.07271) to 0.
# Setting small value of oil (-0.07485) to 0.
# Setting small value of oil (-0.07485) to 0.
# Setting small value of oil (-0.07485) to 0.
# Setting small value of oil (-0.07485) to 0.
# Setting small value of oil (-0.07485) to 0.
# Setting small value of oil (-0.07485) to 0.
# Setting small value of oil (-0.07485) to 0.
# Setting small value of oil (-0.07485) to 0.
# Setting small value of oil (-0.07485) to 0.
# Setting small value of oil (-0.07281) to 0.
# Setting small value of oil (-0.07281) to 0.
# Setting small value of oil (-0.07281) to 0.
# Setting small value of oil (-0.07281) to 0.
# Setting small value of oil (-0.07281) to 0.
# Setting small value of oil (-0.07281) to 0.
# Setting small value of oil (-0.07281) to 0.
# Setting small value of oil (-0.07281) to 0.
# Setting small value of oil (-0.07281) to 0.
# Setting small value of oil (-0.07312) to 0.
# Setting small value of oil (-0.07312) to 0.
# Setting small value of oil (-0.07312) to 0.
# Setting small value of oil (-0.07312) to 0.
# Setting small value of oil (-0.07312) to 0.
# Setting small value of oil (-0.07312) to 0.
# Setting small value of oil (-0.07312) to 0.
# Setting small value of oil (-0.07312) to 0.
# Setting small value of oil (-0.07312) to 0.
# Setting small value of oil (-0.07229) to 0.
# Setting small value of oil (-0.07229) to 0.
# Setting small value of oil (-0.07229) to 0.
# Setting small value of oil (-0.07229) to 0.
# Setting small value of oil (-0.07229) to 0.
# Setting small value of oil (-0.07229) to 0.
# Setting small value of oil (-0.07229) to 0.
# Setting small value of oil (-0.07229) to 0.
# Setting small value of oil (-0.07229) to 0.
# Setting small value of oil (-0.07492) to 0.
# Setting small value of oil (-0.07492) to 0.
# Setting small value of oil (-0.07492) to 0.
# Setting small value of oil (-0.07492) to 0.
# Setting small value of oil (-0.07492) to 0.
# Setting small value of oil (-0.07492) to 0.
# Setting small value of oil (-0.07492) to 0.
# Setting small value of oil (-0.07492) to 0.
# Setting small value of oil (-0.07492) to 0.
# Setting small value of oil (-0.07204) to 0.
# Setting small value of oil (-0.07204) to 0.
# Setting small value of oil (-0.07204) to 0.
# Setting small value of oil (-0.07204) to 0.
# Setting small value of oil (-0.07204) to 0.
# Setting small value of oil (-0.07204) to 0.
# Setting small value of oil (-0.07204) to 0.
# Setting small value of oil (-0.07204) to 0.
# Setting small value of oil (-0.07204) to 0.
# Setting small value of oil (-0.07126) to 0.
# Setting small value of oil (-0.07126) to 0.
# Setting small value of oil (-0.07126) to 0.
# Setting small value of oil (-0.07126) to 0.
# Setting small value of oil (-0.07126) to 0.
# Setting small value of oil (-0.07126) to 0.
# Setting small value of oil (-0.07126) to 0.
# Setting small value of oil (-0.07126) to 0.
# Setting small value of oil (-0.07126) to 0.
# Setting small value of oil (-0.07136) to 0.
# Setting small value of oil (-0.07136) to 0.
# Setting small value of oil (-0.07136) to 0.
# Setting small value of oil (-0.07136) to 0.
# Setting small value of oil (-0.07136) to 0.
# Setting small value of oil (-0.07136) to 0.
# Setting small value of oil (-0.07136) to 0.
# Setting small value of oil (-0.07136) to 0.
# Setting small value of oil (-0.07136) to 0.
# Setting small value of oil (-0.07024) to 0.
# Setting small value of oil (-0.07024) to 0.
# Setting small value of oil (-0.07024) to 0.
# Setting small value of oil (-0.07024) to 0.
# Setting small value of oil (-0.07024) to 0.
# Setting small value of oil (-0.07024) to 0.
# Setting small value of oil (-0.07024) to 0.
# Setting small value of oil (-0.07024) to 0.
# Setting small value of oil (-0.07024) to 0.
# Setting small value of oil (-0.0711) to 0.
# Setting small value of oil (-0.0711) to 0.
# Setting small value of oil (-0.0711) to 0.
# Setting small value of oil (-0.0711) to 0.
# Setting small value of oil (-0.0711) to 0.
# Setting small value of oil (-0.0711) to 0.
# Setting small value of oil (-0.0711) to 0.
# Setting small value of oil (-0.0711) to 0.
# Setting small value of oil (-0.0711) to 0.
# Setting small value of oil (-0.07794) to 0.
# Setting small value of oil (-0.07794) to 0.
# Setting small value of oil (-0.07794) to 0.
# Setting small value of oil (-0.07794) to 0.
# Setting small value of oil (-0.07794) to 0.
# Setting small value of oil (-0.07794) to 0.
# Setting small value of oil (-0.07794) to 0.
# Setting small value of oil (-0.07794) to 0.
# Setting small value of oil (-0.07794) to 0.
# Setting small value of oil (-0.08357) to 0.
# Setting small value of oil (-0.08357) to 0.
# Setting small value of oil (-0.08357) to 0.
# Setting small value of oil (-0.08357) to 0.
# Setting small value of oil (-0.08357) to 0.
# Setting small value of oil (-0.08357) to 0.
# Setting small value of oil (-0.08357) to 0.
# Setting small value of oil (-0.08357) to 0.
# Setting small value of oil (-0.08357) to 0.
# Setting small value of oil (-0.08595) to 0.
# Setting small value of oil (-0.08595) to 0.
# Setting small value of oil (-0.08595) to 0.
# Setting small value of oil (-0.08595) to 0.
# Setting small value of oil (-0.08595) to 0.
# Setting small value of oil (-0.08595) to 0.
# Setting small value of oil (-0.08595) to 0.
# Setting small value of oil (-0.08595) to 0.
# Setting small value of oil (-0.08595) to 0.
# Setting small value of oil (-0.09022) to 0.
# Setting small value of oil (-0.09022) to 0.
# Setting small value of oil (-0.09022) to 0.
# Setting small value of oil (-0.09022) to 0.
# Setting small value of oil (-0.09022) to 0.
# Setting small value of oil (-0.09022) to 0.
# Setting small value of oil (-0.09022) to 0.
# Setting small value of oil (-0.09022) to 0.
# Setting small value of oil (-0.09022) to 0.
# Setting small value of oil (-0.09359) to 0.
# Setting small value of oil (-0.09359) to 0.
# Setting small value of oil (-0.09359) to 0.
# Setting small value of oil (-0.09359) to 0.
# Setting small value of oil (-0.09359) to 0.
# Setting small value of oil (-0.09359) to 0.
# Setting small value of oil (-0.09359) to 0.
# Setting small value of oil (-0.09359) to 0.
# Setting small value of oil (-0.09359) to 0.
# Setting small value of oil (-0.08765) to 0.
# Setting small value of oil (-0.08765) to 0.
# Setting small value of oil (-0.08765) to 0.
# Setting small value of oil (-0.08765) to 0.
# Setting small value of oil (-0.08765) to 0.
# Setting small value of oil (-0.08765) to 0.
# Setting small value of oil (-0.08765) to 0.
# Setting small value of oil (-0.08765) to 0.
# Setting small value of oil (-0.08765) to 0.
# Setting small value of oil (-0.09225) to 0.
# Setting small value of oil (-0.09225) to 0.
# Setting small value of oil (-0.09225) to 0.
# Setting small value of oil (-0.09225) to 0.
# Setting small value of oil (-0.09225) to 0.
# Setting small value of oil (-0.09225) to 0.
# Setting small value of oil (-0.09225) to 0.
# Setting small value of oil (-0.09225) to 0.
# Setting small value of oil (-0.09225) to 0.
# Setting small value of oil (-0.09517) to 0.
# Setting small value of oil (-0.09517) to 0.
# Setting small value of oil (-0.09517) to 0.
# Setting small value of oil (-0.09517) to 0.
# Setting small value of oil (-0.09517) to 0.
# Setting small value of oil (-0.09517) to 0.
# Setting small value of oil (-0.09517) to 0.
# Setting small value of oil (-0.09517) to 0.
# Setting small value of oil (-0.09517) to 0.
# Setting small value of oil (-0.09079) to 0.
# Setting small value of oil (-0.09079) to 0.
# Setting small value of oil (-0.09079) to 0.
# Setting small value of oil (-0.09079) to 0.
# Setting small value of oil (-0.09079) to 0.
# Setting small value of oil (-0.09079) to 0.
# Setting small value of oil (-0.09079) to 0.
# Setting small value of oil (-0.09079) to 0.
# Setting small value of oil (-0.09079) to 0.
# Setting small value of oil (-0.08652) to 0.
# Setting small value of oil (-0.08652) to 0.
# Setting small value of oil (-0.08652) to 0.
# Setting small value of oil (-0.08652) to 0.
# Setting small value of oil (-0.08652) to 0.
# Setting small value of oil (-0.08652) to 0.
# Setting small value of oil (-0.08652) to 0.
# Setting small value of oil (-0.08652) to 0.
# Setting small value of oil (-0.08652) to 0.
# Setting small value of oil (-0.087) to 0.
# Setting small value of oil (-0.087) to 0.
# Setting small value of oil (-0.087) to 0.
# Setting small value of oil (-0.087) to 0.
# Setting small value of oil (-0.087) to 0.
# Setting small value of oil (-0.087) to 0.
# Setting small value of oil (-0.087) to 0.
# Setting small value of oil (-0.087) to 0.
# Setting small value of oil (-0.087) to 0.
# Setting small value of oil (-0.08641) to 0.
# Setting small value of oil (-0.08641) to 0.
# Setting small value of oil (-0.08641) to 0.
# Setting small value of oil (-0.08641) to 0.
# Setting small value of oil (-0.08641) to 0.
# Setting small value of oil (-0.08641) to 0.
# Setting small value of oil (-0.08641) to 0.
# Setting small value of oil (-0.08641) to 0.
# Setting small value of oil (-0.08641) to 0.
# Setting small value of oil (-0.08455) to 0.
# Setting small value of oil (-0.08455) to 0.
# Setting small value of oil (-0.08455) to 0.
# Setting small value of oil (-0.08455) to 0.
# Setting small value of oil (-0.08455) to 0.
# Setting small value of oil (-0.08455) to 0.
# Setting small value of oil (-0.08455) to 0.
# Setting small value of oil (-0.08455) to 0.
# Setting small value of oil (-0.08455) to 0.
# Setting small value of oil (-0.07662) to 0.
# Setting small value of oil (-0.07662) to 0.
# Setting small value of oil (-0.07662) to 0.
# Setting small value of oil (-0.07662) to 0.
# Setting small value of oil (-0.07662) to 0.
# Setting small value of oil (-0.07662) to 0.
# Setting small value of oil (-0.07662) to 0.
# Setting small value of oil (-0.07662) to 0.
# Setting small value of oil (-0.07662) to 0.
# Setting small value of oil (-0.07624) to 0.
# Setting small value of oil (-0.07624) to 0.
# Setting small value of oil (-0.07624) to 0.
# Setting small value of oil (-0.07624) to 0.
# Setting small value of oil (-0.07624) to 0.
# Setting small value of oil (-0.07624) to 0.
# Setting small value of oil (-0.07624) to 0.
# Setting small value of oil (-0.07624) to 0.
# Setting small value of oil (-0.07624) to 0.
# Setting small value of oil (-0.07549) to 0.
# Setting small value of oil (-0.07549) to 0.
# Setting small value of oil (-0.07549) to 0.
# Setting small value of oil (-0.07549) to 0.
# Setting small value of oil (-0.07549) to 0.
# Setting small value of oil (-0.07549) to 0.
# Setting small value of oil (-0.07549) to 0.
# Setting small value of oil (-0.07549) to 0.
# Setting small value of oil (-0.07549) to 0.
# Setting small value of oil (-0.07735) to 0.
# Setting small value of oil (-0.07735) to 0.
# Setting small value of oil (-0.07735) to 0.
# Setting small value of oil (-0.07735) to 0.
# Setting small value of oil (-0.07735) to 0.
# Setting small value of oil (-0.07735) to 0.
# Setting small value of oil (-0.07735) to 0.
# Setting small value of oil (-0.07735) to 0.
# Setting small value of oil (-0.07735) to 0.
# Setting small value of oil (-0.07619) to 0.
# Setting small value of oil (-0.07619) to 0.
# Setting small value of oil (-0.07619) to 0.
# Setting small value of oil (-0.07619) to 0.
# Setting small value of oil (-0.07619) to 0.
# Setting small value of oil (-0.07619) to 0.
# Setting small value of oil (-0.07619) to 0.
# Setting small value of oil (-0.07619) to 0.
# Setting small value of oil (-0.07619) to 0.
# Setting small value of oil (-0.07213) to 0.
# Setting small value of oil (-0.07213) to 0.
# Setting small value of oil (-0.07213) to 0.
# Setting small value of oil (-0.07213) to 0.
# Setting small value of oil (-0.07213) to 0.
# Setting small value of oil (-0.07213) to 0.
# Setting small value of oil (-0.07213) to 0.
# Setting small value of oil (-0.07213) to 0.
# Setting small value of oil (-0.07213) to 0.
# Setting small value of oil (-0.07276) to 0.
# Setting small value of oil (-0.07276) to 0.
# Setting small value of oil (-0.07276) to 0.
# Setting small value of oil (-0.07276) to 0.
# Setting small value of oil (-0.07276) to 0.
# Setting small value of oil (-0.07276) to 0.
# Setting small value of oil (-0.07276) to 0.
# Setting small value of oil (-0.07276) to 0.
# Setting small value of oil (-0.07276) to 0.
# Setting small value of oil (-0.0746) to 0.
# Setting small value of oil (-0.0746) to 0.
# Setting small value of oil (-0.0746) to 0.
# Setting small value of oil (-0.0746) to 0.
# Setting small value of oil (-0.0746) to 0.
# Setting small value of oil (-0.0746) to 0.
# Setting small value of oil (-0.0746) to 0.
# Setting small value of oil (-0.0746) to 0.
# Setting small value of oil (-0.0746) to 0.
# Setting small value of oil (-0.06953) to 0.
# Setting small value of oil (-0.06953) to 0.
# Setting small value of oil (-0.06953) to 0.
# Setting small value of oil (-0.06953) to 0.
# Setting small value of oil (-0.06953) to 0.
# Setting small value of oil (-0.06953) to 0.
# Setting small value of oil (-0.06953) to 0.
# Setting small value of oil (-0.06953) to 0.
# Setting small value of oil (-0.06953) to 0.
# Setting small value of oil (-0.06914) to 0.
# Setting small value of oil (-0.06914) to 0.
# Setting small value of oil (-0.06914) to 0.
# Setting small value of oil (-0.06914) to 0.
# Setting small value of oil (-0.06914) to 0.
# Setting small value of oil (-0.06914) to 0.
# Setting small value of oil (-0.06914) to 0.
# Setting small value of oil (-0.06914) to 0.
# Setting small value of oil (-0.06914) to 0.
# Setting small value of oil (-0.07521) to 0.
# Setting small value of oil (-0.07521) to 0.
# Setting small value of oil (-0.07521) to 0.
# Setting small value of oil (-0.07521) to 0.
# Setting small value of oil (-0.07521) to 0.
# Setting small value of oil (-0.07521) to 0.
# Setting small value of oil (-0.07521) to 0.
# Setting small value of oil (-0.07521) to 0.
# Setting small value of oil (-0.07521) to 0.
# Setting small value of oil (-0.07465) to 0.
# Setting small value of oil (-0.07465) to 0.
# Setting small value of oil (-0.07465) to 0.
# Setting small value of oil (-0.07465) to 0.
# Setting small value of oil (-0.07465) to 0.
# Setting small value of oil (-0.07465) to 0.
# Setting small value of oil (-0.07465) to 0.
# Setting small value of oil (-0.07465) to 0.
# Setting small value of oil (-0.07465) to 0.
# Setting small value of oil (-0.07666) to 0.
# Setting small value of oil (-0.07666) to 0.
# Setting small value of oil (-0.07666) to 0.
# Setting small value of oil (-0.07666) to 0.
# Setting small value of oil (-0.07666) to 0.
# Setting small value of oil (-0.07666) to 0.
# Setting small value of oil (-0.07666) to 0.
# Setting small value of oil (-0.07666) to 0.
# Setting small value of oil (-0.07666) to 0.
# Setting small value of oil (-0.07429) to 0.
# Setting small value of oil (-0.07429) to 0.
# Setting small value of oil (-0.07429) to 0.
# Setting small value of oil (-0.07429) to 0.
# Setting small value of oil (-0.07429) to 0.
# Setting small value of oil (-0.07429) to 0.
# Setting small value of oil (-0.07429) to 0.
# Setting small value of oil (-0.07429) to 0.
# Setting small value of oil (-0.07429) to 0.
# Setting small value of oil (-0.073) to 0.
# Setting small value of oil (-0.073) to 0.
# Setting small value of oil (-0.073) to 0.
# Setting small value of oil (-0.073) to 0.
# Setting small value of oil (-0.073) to 0.
# Setting small value of oil (-0.073) to 0.
# Setting small value of oil (-0.073) to 0.
# Setting small value of oil (-0.073) to 0.
# Setting small value of oil (-0.073) to 0.
# Setting small value of oil (-0.07414) to 0.
# Setting small value of oil (-0.07414) to 0.
# Setting small value of oil (-0.07414) to 0.
# Setting small value of oil (-0.07414) to 0.
# Setting small value of oil (-0.07414) to 0.
# Setting small value of oil (-0.07414) to 0.
# Setting small value of oil (-0.07414) to 0.
# Setting small value of oil (-0.07414) to 0.
# Setting small value of oil (-0.07414) to 0.
# Setting small value of oil (-0.07095) to 0.
# Setting small value of oil (-0.07095) to 0.
# Setting small value of oil (-0.07095) to 0.
# Setting small value of oil (-0.07095) to 0.
# Setting small value of oil (-0.07095) to 0.
# Setting small value of oil (-0.07095) to 0.
# Setting small value of oil (-0.07095) to 0.
# Setting small value of oil (-0.07095) to 0.
# Setting small value of oil (-0.07095) to 0.
# Setting small value of oil (-0.06988) to 0.
# Setting small value of oil (-0.06988) to 0.
# Setting small value of oil (-0.06988) to 0.
# Setting small value of oil (-0.06988) to 0.
# Setting small value of oil (-0.06988) to 0.
# Setting small value of oil (-0.06988) to 0.
# Setting small value of oil (-0.06988) to 0.
# Setting small value of oil (-0.06988) to 0.
# Setting small value of oil (-0.06988) to 0.
# Setting small value of oil (-0.07126) to 0.
# Setting small value of oil (-0.07126) to 0.
# Setting small value of oil (-0.07126) to 0.
# Setting small value of oil (-0.07126) to 0.
# Setting small value of oil (-0.07126) to 0.
# Setting small value of oil (-0.07126) to 0.
# Setting small value of oil (-0.07126) to 0.
# Setting small value of oil (-0.07126) to 0.
# Setting small value of oil (-0.07126) to 0.
# Setting small value of oil (-0.06689) to 0.
# Setting small value of oil (-0.06689) to 0.
# Setting small value of oil (-0.06689) to 0.
# Setting small value of oil (-0.06689) to 0.
# Setting small value of oil (-0.06689) to 0.
# Setting small value of oil (-0.06689) to 0.
# Setting small value of oil (-0.06689) to 0.
# Setting small value of oil (-0.06689) to 0.
# Setting small value of oil (-0.06689) to 0.
# Setting small value of oil (-0.06873) to 0.
# Setting small value of oil (-0.06873) to 0.
# Setting small value of oil (-0.06873) to 0.
# Setting small value of oil (-0.06873) to 0.
# Setting small value of oil (-0.06873) to 0.
# Setting small value of oil (-0.06873) to 0.
# Setting small value of oil (-0.06873) to 0.
# Setting small value of oil (-0.06873) to 0.
# Setting small value of oil (-0.06873) to 0.
# Setting small value of oil (-0.06546) to 0.
# Setting small value of oil (-0.06546) to 0.
# Setting small value of oil (-0.06546) to 0.
# Setting small value of oil (-0.06546) to 0.
# Setting small value of oil (-0.06546) to 0.
# Setting small value of oil (-0.06546) to 0.
# Setting small value of oil (-0.06546) to 0.
# Setting small value of oil (-0.06546) to 0.
# Setting small value of oil (-0.06546) to 0.
# Setting small value of oil (-0.07253) to 0.
# Setting small value of oil (-0.07253) to 0.
# Setting small value of oil (-0.07253) to 0.
# Setting small value of oil (-0.07253) to 0.
# Setting small value of oil (-0.07253) to 0.
# Setting small value of oil (-0.07253) to 0.
# Setting small value of oil (-0.07253) to 0.
# Setting small value of oil (-0.07253) to 0.
# Setting small value of oil (-0.07253) to 0.
# Setting small value of oil (-0.0718) to 0.
# Setting small value of oil (-0.0718) to 0.
# Setting small value of oil (-0.0718) to 0.
# Setting small value of oil (-0.0718) to 0.
# Setting small value of oil (-0.0718) to 0.
# Setting small value of oil (-0.0718) to 0.
# Setting small value of oil (-0.0718) to 0.
# Setting small value of oil (-0.0718) to 0.
# Setting small value of oil (-0.0718) to 0.
# Setting small value of oil (-0.07213) to 0.
# Setting small value of oil (-0.07213) to 0.
# Setting small value of oil (-0.07213) to 0.
# Setting small value of oil (-0.07213) to 0.
# Setting small value of oil (-0.07213) to 0.
# Setting small value of oil (-0.07213) to 0.
# Setting small value of oil (-0.07213) to 0.
# Setting small value of oil (-0.07213) to 0.
# Setting small value of oil (-0.07213) to 0.
# Setting small value of oil (-0.06356) to 0.
# Setting small value of oil (-0.06356) to 0.
# Setting small value of oil (-0.06356) to 0.
# Setting small value of oil (-0.06356) to 0.
# Setting small value of oil (-0.06356) to 0.
# Setting small value of oil (-0.06356) to 0.
# Setting small value of oil (-0.06356) to 0.
# Setting small value of oil (-0.06356) to 0.
# Setting small value of oil (-0.06356) to 0.
# Setting small value of oil (-0.06265) to 0.
# Setting small value of oil (-0.06265) to 0.
# Setting small value of oil (-0.06265) to 0.
# Setting small value of oil (-0.06265) to 0.
# Setting small value of oil (-0.06265) to 0.
# Setting small value of oil (-0.06265) to 0.
# Setting small value of oil (-0.06265) to 0.
# Setting small value of oil (-0.06265) to 0.
# Setting small value of oil (-0.06265) to 0.
# Setting small value of oil (-0.0608) to 0.
# Setting small value of oil (-0.0608) to 0.
# Setting small value of oil (-0.0608) to 0.
# Setting small value of oil (-0.0608) to 0.
# Setting small value of oil (-0.0608) to 0.
# Setting small value of oil (-0.0608) to 0.
# Setting small value of oil (-0.0608) to 0.
# Setting small value of oil (-0.0608) to 0.
# Setting small value of oil (-0.0608) to 0.
# Setting small value of oil (-0.0635) to 0.
# Setting small value of oil (-0.0635) to 0.
# Setting small value of oil (-0.0635) to 0.
# Setting small value of oil (-0.0635) to 0.
# Setting small value of oil (-0.0635) to 0.
# Setting small value of oil (-0.0635) to 0.
# Setting small value of oil (-0.0635) to 0.
# Setting small value of oil (-0.0635) to 0.
# Setting small value of oil (-0.0635) to 0.
# Setting small value of oil (-0.0663) to 0.
# Setting small value of oil (-0.0663) to 0.
# Setting small value of oil (-0.0663) to 0.
# Setting small value of oil (-0.0663) to 0.
# Setting small value of oil (-0.0663) to 0.
# Setting small value of oil (-0.0663) to 0.
# ...
# Setting small value of oil (-0.06799) to 0.
# Setting small value of oil (-0.06799) to 0.
# Setting small value of oil (-0.06799) to 0.
# Setting small value of oil (-0.06799) to 0.
# Setting small value of oil (-0.06871) to 0.
# Setting small value of oil (-0.06871) to 0.
# Setting small value of oil (-0.06871) to 0.
# Setting small value of oil (-0.06871) to 0.
# Setting small value of oil (-0.06871) to 0.
# Setting small value of oil (-0.06871) to 0.
# Setting small value of oil (-0.06871) to 0.
# Setting small value of oil (-0.06871) to 0.
# Setting small value of oil (-0.06871) to 0.
# Setting small value of oil (-0.06382) to 0.
# Setting small value of oil (-0.06382) to 0.
# Setting small value of oil (-0.06382) to 0.
# Setting small value of oil (-0.06382) to 0.
# Setting small value of oil (-0.06382) to 0.
# Setting small value of oil (-0.06382) to 0.
# Setting small value of oil (-0.06382) to 0.
# Setting small value of oil (-0.06382) to 0.
# Setting small value of oil (-0.06382) to 0.
# Setting small value of oil (-0.06734) to 0.
# Setting small value of oil (-0.06734) to 0.
# Setting small value of oil (-0.06734) to 0.
# Setting small value of oil (-0.06734) to 0.
# Setting small value of oil (-0.06734) to 0.
# Setting small value of oil (-0.06734) to 0.
# Setting small value of oil (-0.06734) to 0.
# Setting small value of oil (-0.06734) to 0.
# Setting small value of oil (-0.06734) to 0.
# Setting small value of oil (-0.06715) to 0.
# Setting small value of oil (-0.06715) to 0.
# Setting small value of oil (-0.06715) to 0.
# Setting small value of oil (-0.06715) to 0.
# Setting small value of oil (-0.06715) to 0.
# Setting small value of oil (-0.06715) to 0.
# Setting small value of oil (-0.06715) to 0.
# Setting small value of oil (-0.06715) to 0.
# Setting small value of oil (-0.06715) to 0.
# Setting small value of oil (-0.06216) to 0.
# Setting small value of oil (-0.06216) to 0.
# Setting small value of oil (-0.06216) to 0.
# Setting small value of oil (-0.06216) to 0.
# Setting small value of oil (-0.06216) to 0.
# Setting small value of oil (-0.06216) to 0.
# Setting small value of oil (-0.06216) to 0.
# Setting small value of oil (-0.06216) to 0.
# Setting small value of oil (-0.06216) to 0.
# Setting small value of oil (-0.06244) to 0.
# Setting small value of oil (-0.06244) to 0.
# Setting small value of oil (-0.06244) to 0.
# Setting small value of oil (-0.06244) to 0.
# Setting small value of oil (-0.06244) to 0.
# Setting small value of oil (-0.06244) to 0.
# Setting small value of oil (-0.06244) to 0.
# Setting small value of oil (-0.06244) to 0.
# Setting small value of oil (-0.06244) to 0.
# Setting small value of oil (-0.07066) to 0.
# Setting small value of oil (-0.07066) to 0.
# Setting small value of oil (-0.07066) to 0.
# Setting small value of oil (-0.07066) to 0.
# Setting small value of oil (-0.07066) to 0.
# Setting small value of oil (-0.07066) to 0.
# Setting small value of oil (-0.07066) to 0.
# Setting small value of oil (-0.07066) to 0.
# Setting small value of oil (-0.07066) to 0.
# Setting small value of oil (-0.07169) to 0.
# Setting small value of oil (-0.07169) to 0.
# Setting small value of oil (-0.07169) to 0.
# Setting small value of oil (-0.07169) to 0.
# Setting small value of oil (-0.07169) to 0.
# Setting small value of oil (-0.07169) to 0.
# Setting small value of oil (-0.07169) to 0.
# Setting small value of oil (-0.07169) to 0.
# Setting small value of oil (-0.07169) to 0.
# Setting small value of oil (-0.07332) to 0.
# Setting small value of oil (-0.07332) to 0.
# Setting small value of oil (-0.07332) to 0.
# Setting small value of oil (-0.07332) to 0.
# Setting small value of oil (-0.07332) to 0.
# Setting small value of oil (-0.07332) to 0.
# Setting small value of oil (-0.07332) to 0.
# Setting small value of oil (-0.07332) to 0.
# Setting small value of oil (-0.07332) to 0.
# Setting small value of oil (-0.06894) to 0.
# Setting small value of oil (-0.06894) to 0.
# Setting small value of oil (-0.06894) to 0.
# Setting small value of oil (-0.06894) to 0.
# Setting small value of oil (-0.06894) to 0.
# Setting small value of oil (-0.06894) to 0.
# Setting small value of oil (-0.06894) to 0.
# Setting small value of oil (-0.06894) to 0.
# Setting small value of oil (-0.06894) to 0.
# Setting small value of oil (-0.07246) to 0.
# Setting small value of oil (-0.07246) to 0.
# Setting small value of oil (-0.07246) to 0.
# Setting small value of oil (-0.07246) to 0.
# Setting small value of oil (-0.07246) to 0.
# Setting small value of oil (-0.07246) to 0.
# Setting small value of oil (-0.07246) to 0.
# Setting small value of oil (-0.07246) to 0.
# Setting small value of oil (-0.07246) to 0.
# Setting small value of oil (-0.06425) to 0.
# Setting small value of oil (-0.06425) to 0.
# Setting small value of oil (-0.06425) to 0.
# Setting small value of oil (-0.06425) to 0.
# Setting small value of oil (-0.06425) to 0.
# Setting small value of oil (-0.06425) to 0.
# Setting small value of oil (-0.06425) to 0.
# Setting small value of oil (-0.06425) to 0.
# Setting small value of oil (-0.06425) to 0.
# Setting small value of oil (-0.06376) to 0.
# Setting small value of oil (-0.06376) to 0.
# Setting small value of oil (-0.06376) to 0.
# Setting small value of oil (-0.06376) to 0.
# Setting small value of oil (-0.06376) to 0.
# Setting small value of oil (-0.06376) to 0.
# Setting small value of oil (-0.06376) to 0.
# Setting small value of oil (-0.06376) to 0.
# Setting small value of oil (-0.06376) to 0.
# Setting small value of oil (-0.06659) to 0.
# Setting small value of oil (-0.06659) to 0.
# Setting small value of oil (-0.06659) to 0.
# Setting small value of oil (-0.06659) to 0.
# Setting small value of oil (-0.06659) to 0.
# Setting small value of oil (-0.06659) to 0.
# Setting small value of oil (-0.06659) to 0.
# Setting small value of oil (-0.06659) to 0.
# Setting small value of oil (-0.06659) to 0.
# Setting small value of oil (-0.06668) to 0.
# Setting small value of oil (-0.06668) to 0.
# Setting small value of oil (-0.06668) to 0.
# Setting small value of oil (-0.06668) to 0.
# Setting small value of oil (-0.06668) to 0.
# Setting small value of oil (-0.06668) to 0.
# Setting small value of oil (-0.06668) to 0.
# Setting small value of oil (-0.06668) to 0.
# Setting small value of oil (-0.06668) to 0.
# Setting small value of oil (-0.06827) to 0.
# Setting small value of oil (-0.06827) to 0.
# Setting small value of oil (-0.06827) to 0.
# Setting small value of oil (-0.06827) to 0.
# Setting small value of oil (-0.06827) to 0.
# Setting small value of oil (-0.06827) to 0.
# Setting small value of oil (-0.06827) to 0.
# Setting small value of oil (-0.06827) to 0.
# Setting small value of oil (-0.06827) to 0.
# Setting small value of oil (-0.06712) to 0.
# Setting small value of oil (-0.06712) to 0.
# Setting small value of oil (-0.06712) to 0.
# Setting small value of oil (-0.06712) to 0.
# Setting small value of oil (-0.06712) to 0.
# Setting small value of oil (-0.06712) to 0.
# Setting small value of oil (-0.06712) to 0.
# Setting small value of oil (-0.06712) to 0.
# Setting small value of oil (-0.06712) to 0.
# Setting small value of oil (-0.06924) to 0.
# Setting small value of oil (-0.06924) to 0.
# Setting small value of oil (-0.06924) to 0.
# Setting small value of oil (-0.06924) to 0.
# Setting small value of oil (-0.06924) to 0.
# Setting small value of oil (-0.06924) to 0.
# Setting small value of oil (-0.06924) to 0.
# Setting small value of oil (-0.06924) to 0.
# Setting small value of oil (-0.06924) to 0.
# Setting small value of oil (-0.07111) to 0.
# Setting small value of oil (-0.07111) to 0.
# Setting small value of oil (-0.07111) to 0.
# Setting small value of oil (-0.07111) to 0.
# Setting small value of oil (-0.07111) to 0.
# Setting small value of oil (-0.07111) to 0.
# Setting small value of oil (-0.07111) to 0.
# Setting small value of oil (-0.07111) to 0.
# Setting small value of oil (-0.07111) to 0.
# Setting small value of oil (-0.06818) to 0.
# Setting small value of oil (-0.06818) to 0.
# Setting small value of oil (-0.06818) to 0.
# Setting small value of oil (-0.06818) to 0.
# Setting small value of oil (-0.06818) to 0.
# Setting small value of oil (-0.06818) to 0.
# Setting small value of oil (-0.06818) to 0.
# Setting small value of oil (-0.06818) to 0.
# Setting small value of oil (-0.06818) to 0.
# Setting small value of oil (-0.06605) to 0.
# Setting small value of oil (-0.06605) to 0.
# Setting small value of oil (-0.06605) to 0.
# Setting small value of oil (-0.06605) to 0.
# Setting small value of oil (-0.06605) to 0.
# Setting small value of oil (-0.06605) to 0.
# Setting small value of oil (-0.06605) to 0.
# Setting small value of oil (-0.06605) to 0.
# Setting small value of oil (-0.06605) to 0.
# Setting small value of oil (-0.07028) to 0.
# Setting small value of oil (-0.07028) to 0.
# Setting small value of oil (-0.07028) to 0.
# Setting small value of oil (-0.07028) to 0.
# Setting small value of oil (-0.07028) to 0.
# Setting small value of oil (-0.07028) to 0.
# Setting small value of oil (-0.07028) to 0.
# Setting small value of oil (-0.07028) to 0.
# Setting small value of oil (-0.07028) to 0.
# Setting small value of oil (-0.07271) to 0.
# Setting small value of oil (-0.07271) to 0.
# Setting small value of oil (-0.07271) to 0.
# Setting small value of oil (-0.07271) to 0.
# Setting small value of oil (-0.07271) to 0.
# Setting small value of oil (-0.07271) to 0.
# Setting small value of oil (-0.07271) to 0.
# Setting small value of oil (-0.07271) to 0.
# Setting small value of oil (-0.07271) to 0.
# Setting small value of oil (-0.06861) to 0.
# Setting small value of oil (-0.06861) to 0.
# Setting small value of oil (-0.06861) to 0.
# Setting small value of oil (-0.06861) to 0.
# Setting small value of oil (-0.06861) to 0.
# Setting small value of oil (-0.06861) to 0.
# Setting small value of oil (-0.06861) to 0.
# Setting small value of oil (-0.06861) to 0.
# Setting small value of oil (-0.06861) to 0.
# Setting small value of oil (-0.06891) to 0.
# Setting small value of oil (-0.06891) to 0.
# Setting small value of oil (-0.06891) to 0.
# Setting small value of oil (-0.06891) to 0.
# Setting small value of oil (-0.06891) to 0.
# Setting small value of oil (-0.06891) to 0.
# Setting small value of oil (-0.06891) to 0.
# Setting small value of oil (-0.06891) to 0.
# Setting small value of oil (-0.06891) to 0.
# Setting small value of oil (-0.06558) to 0.
# Setting small value of oil (-0.06558) to 0.
# Setting small value of oil (-0.06558) to 0.
# Setting small value of oil (-0.06558) to 0.
# Setting small value of oil (-0.06558) to 0.
# Setting small value of oil (-0.06558) to 0.
# Setting small value of oil (-0.06558) to 0.
# Setting small value of oil (-0.06558) to 0.
# Setting small value of oil (-0.06558) to 0.
# Setting small value of oil (-0.07011) to 0.
# Setting small value of oil (-0.07011) to 0.
# Setting small value of oil (-0.07011) to 0.
# Setting small value of oil (-0.07011) to 0.
# Setting small value of oil (-0.07011) to 0.
# Setting small value of oil (-0.07011) to 0.
# Setting small value of oil (-0.07011) to 0.
# Setting small value of oil (-0.07011) to 0.
# Setting small value of oil (-0.07011) to 0.
# Setting small value of oil (-0.06669) to 0.
# Setting small value of oil (-0.06669) to 0.
# Setting small value of oil (-0.06669) to 0.
# Setting small value of oil (-0.06669) to 0.
# Setting small value of oil (-0.06669) to 0.
# Setting small value of oil (-0.06669) to 0.
# Setting small value of oil (-0.06669) to 0.
# Setting small value of oil (-0.06669) to 0.
# Setting small value of oil (-0.06669) to 0.
# Setting small value of oil (-0.07503) to 0.
# Setting small value of oil (-0.07503) to 0.
# Setting small value of oil (-0.07503) to 0.
# Setting small value of oil (-0.07503) to 0.
# Setting small value of oil (-0.07503) to 0.
# Setting small value of oil (-0.07503) to 0.
# Setting small value of oil (-0.07503) to 0.
# Setting small value of oil (-0.07503) to 0.
# Setting small value of oil (-0.07503) to 0.
# Setting small value of oil (-0.06985) to 0.
# Setting small value of oil (-0.06985) to 0.
# Setting small value of oil (-0.06985) to 0.
# Setting small value of oil (-0.06985) to 0.
# Setting small value of oil (-0.06985) to 0.
# Setting small value of oil (-0.06985) to 0.
# Setting small value of oil (-0.06985) to 0.
# Setting small value of oil (-0.06985) to 0.
# Setting small value of oil (-0.06985) to 0.
# Setting small value of oil (-0.07034) to 0.
# Setting small value of oil (-0.07034) to 0.
# Setting small value of oil (-0.07034) to 0.
# Setting small value of oil (-0.07034) to 0.
# Setting small value of oil (-0.07034) to 0.
# Setting small value of oil (-0.07034) to 0.
# Setting small value of oil (-0.07034) to 0.
# Setting small value of oil (-0.07034) to 0.
# Setting small value of oil (-0.07034) to 0.
# Setting small value of oil (-0.07213) to 0.
# Setting small value of oil (-0.07213) to 0.
# Setting small value of oil (-0.07213) to 0.
# Setting small value of oil (-0.07213) to 0.
# Setting small value of oil (-0.07213) to 0.
# Setting small value of oil (-0.07213) to 0.
# Setting small value of oil (-0.07213) to 0.
# Setting small value of oil (-0.07213) to 0.
# Setting small value of oil (-0.07213) to 0.
# Setting small value of oil (-0.07272) to 0.
# Setting small value of oil (-0.07272) to 0.
# Setting small value of oil (-0.07272) to 0.
# Setting small value of oil (-0.07272) to 0.
# Setting small value of oil (-0.07272) to 0.
# Setting small value of oil (-0.07272) to 0.
# Setting small value of oil (-0.07272) to 0.
# Setting small value of oil (-0.07272) to 0.
# Setting small value of oil (-0.07272) to 0.
# Setting small value of oil (-0.06895) to 0.
# Setting small value of oil (-0.06895) to 0.
# Setting small value of oil (-0.06895) to 0.
# Setting small value of oil (-0.06895) to 0.
# Setting small value of oil (-0.06895) to 0.
# Setting small value of oil (-0.06895) to 0.
# Setting small value of oil (-0.06895) to 0.
# Setting small value of oil (-0.06895) to 0.
# Setting small value of oil (-0.06895) to 0.
# Setting small value of oil (-0.07268) to 0.
# Setting small value of oil (-0.07268) to 0.
# Setting small value of oil (-0.07268) to 0.
# Setting small value of oil (-0.07268) to 0.
# Setting small value of oil (-0.07268) to 0.
# Setting small value of oil (-0.07268) to 0.
# Setting small value of oil (-0.07268) to 0.
# Setting small value of oil (-0.07268) to 0.
# Setting small value of oil (-0.07268) to 0.
# Setting small value of oil (-0.07084) to 0.
# Setting small value of oil (-0.07084) to 0.
# Setting small value of oil (-0.07084) to 0.
# Setting small value of oil (-0.07084) to 0.
# Setting small value of oil (-0.07084) to 0.
# Setting small value of oil (-0.07084) to 0.
# Setting small value of oil (-0.07084) to 0.
# Setting small value of oil (-0.07084) to 0.
# Setting small value of oil (-0.07084) to 0.
# Setting small value of oil (-0.07576) to 0.
# Setting small value of oil (-0.07576) to 0.
# Setting small value of oil (-0.07576) to 0.
# Setting small value of oil (-0.07576) to 0.
# Setting small value of oil (-0.07576) to 0.
# Setting small value of oil (-0.07576) to 0.
# Setting small value of oil (-0.07576) to 0.
# Setting small value of oil (-0.07576) to 0.
# Setting small value of oil (-0.07576) to 0.
# Setting small value of oil (-0.07111) to 0.
# Setting small value of oil (-0.07111) to 0.
# Setting small value of oil (-0.07111) to 0.
# Setting small value of oil (-0.07111) to 0.
# Setting small value of oil (-0.07111) to 0.
# Setting small value of oil (-0.07111) to 0.
# Setting small value of oil (-0.07111) to 0.
# Setting small value of oil (-0.07111) to 0.
# Setting small value of oil (-0.07111) to 0.
# Setting small value of oil (-0.06783) to 0.
# Setting small value of oil (-0.06783) to 0.
# Setting small value of oil (-0.06783) to 0.
# Setting small value of oil (-0.06783) to 0.
# Setting small value of oil (-0.06783) to 0.
# Setting small value of oil (-0.06783) to 0.
# Setting small value of oil (-0.06783) to 0.
# Setting small value of oil (-0.06783) to 0.
# Setting small value of oil (-0.06783) to 0.
# Setting small value of oil (-0.0618) to 0.
# Setting small value of oil (-0.0618) to 0.
# Setting small value of oil (-0.0618) to 0.
# Setting small value of oil (-0.0618) to 0.
# Setting small value of oil (-0.0618) to 0.
# Setting small value of oil (-0.0618) to 0.
# Setting small value of oil (-0.0618) to 0.
# Setting small value of oil (-0.0618) to 0.

# %%
result
# Out:
# [{'datetime': datetime.datetime(2021, 10, 1, 0, 0, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 5182.0,
#    'gas': 190.1,
#    'oil': 0,
#    'hydro': 115.4,
#    'wind': 1006.0,
#    'biomass': None,
#    'solar': 0.065},
#   'storage': {'battery': None, 'hydro': 0.0},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 1, 0, 5, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 5125.0,
#    'gas': 190.1,
#    'oil': 0,
#    'hydro': 115.4,
#    'wind': 974.4,
#    'biomass': None,
#    'solar': 0.065},
#   'storage': {'battery': None, 'hydro': 0.0},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 1, 0, 10, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 5124.0,
#    'gas': 128.1,
#    'oil': 0,
#    'hydro': 300.5,
#    'wind': 927.6,
#    'biomass': None,
#    'solar': 0.065},
#   'storage': {'battery': None, 'hydro': 0.0},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 1, 0, 15, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 5170.0,
#    'gas': 44.14,
#    'oil': 0,
#    'hydro': 303.6,
#    'wind': 891.2,
#    'biomass': None,
#    'solar': 0.065},
#   'storage': {'battery': None, 'hydro': 0.0},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 1, 0, 20, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 5300.0,
#    'gas': 0.1338,
#    'oil': 0,
#    'hydro': 304.9,
#    'wind': 828.1,
#    'biomass': None,
#    'solar': 0.065},
#   'storage': {'battery': None, 'hydro': 0.0},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 1, 0, 25, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 5316.0,
#    'gas': 0.1237,
#    'oil': 0,
#    'hydro': 292.8,
#    'wind': 816.5,
#    'biomass': None,
#    'solar': 0.065},
#   'storage': {'battery': None, 'hydro': 0.0},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 1, 0, 30, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 5318.0,
#    'gas': 0.1539,
#    'oil': 0,
#    'hydro': 295.1,
#    'wind': 825.5,
#    'biomass': None,
#    'solar': 0.066},
#   'storage': {'battery': None, 'hydro': 0.0},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 1, 0, 35, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 5297.0,
#    'gas': 0.1438,
#    'oil': 0,
#    'hydro': 293.3,
#    'wind': 814.1,
#    'biomass': None,
#    'solar': 0.066},
#   'storage': {'battery': None, 'hydro': 0.0},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 1, 0, 40, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 5374.0,
#    'gas': 0.1237,
#    'oil': 0,
#    'hydro': 276.9,
#    'wind': 791.7,
#    'biomass': None,
#    'solar': 0.066},
#   'storage': {'battery': None, 'hydro': 0.0},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 1, 0, 45, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 5331.0,
#    'gas': 0.1438,
#    'oil': 0,
#    'hydro': 273.5,
#    'wind': 779.0,
#    'biomass': None,
#    'solar': 0.066},
#   'storage': {'battery': None, 'hydro': 0.0},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 1, 0, 50, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 5332.0,
#    'gas': 0.1237,
#    'oil': 0,
#    'hydro': 266.1,
#    'wind': 743.3,
#    'biomass': None,
#    'solar': 0.066},
#   'storage': {'battery': None, 'hydro': 0.0},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 1, 0, 55, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 5320.0,
#    'gas': 0.1237,
#    'oil': 0,
#    'hydro': 272.5,
#    'wind': 695.2,
#    'biomass': None,
#    'solar': 0.066},
#   'storage': {'battery': None, 'hydro': 0.0},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 1, 1, 0, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 5374.0,
#    'gas': 0.1438,
#    'oil': 0,
#    'hydro': 274.7,
#    'wind': 730.9,
#    'biomass': None,
#    'solar': 0.066},
#   'storage': {'battery': None, 'hydro': 0.0},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 1, 1, 5, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 5290.0,
#    'gas': 0.1438,
#    'oil': 0,
#    'hydro': 267.6,
#    'wind': 706.3,
#    'biomass': None,
#    'solar': 0.066},
#   'storage': {'battery': None, 'hydro': 0.0},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 1, 1, 10, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 5271.0,
#    'gas': 0.08352,
#    'oil': 0,
#    'hydro': 248.3,
#    'wind': 615.6,
#    'biomass': None,
#    'solar': 0.066},
#   'storage': {'battery': None, 'hydro': 0.0},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 1, 1, 15, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 5361.0,
#    'gas': 0.1237,
#    'oil': 0,
#    'hydro': 251.2,
#    'wind': 577.9,
#    'biomass': None,
#    'solar': 0.069},
#   'storage': {'battery': None, 'hydro': 0.0},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 1, 1, 20, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 5382.0,
#    'gas': 0.1438,
#    'oil': 0,
#    'hydro': 246.8,
#    'wind': 551.6,
#    'biomass': None,
#    'solar': 0.069},
#   'storage': {'battery': None, 'hydro': 0.0},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 1, 1, 25, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 5354.0,
#    'gas': 0.08352,
#    'oil': 0,
#    'hydro': 248.5,
#    'wind': 527.0,
#    'biomass': None,
#    'solar': 0.069},
#   'storage': {'battery': None, 'hydro': 0.0},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 1, 1, 30, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 5325.0,
#    'gas': 0.1438,
#    'oil': 0,
#    'hydro': 250.6,
#    'wind': 521.9,
#    'biomass': None,
#    'solar': 0.069},
#   'storage': {'battery': None, 'hydro': 0.0},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 1, 1, 35, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 5242.0,
#    'gas': 0.1237,
#    'oil': 0,
#    'hydro': 245.8,
#    'wind': 552.7,
#    'biomass': None,
#    'solar': 0.069},
#   'storage': {'battery': None, 'hydro': 0.0},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 1, 1, 40, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 5221.0,
#    'gas': 0.08352,
#    'oil': 0,
#    'hydro': 238.4,
#    'wind': 574.9,
#    'biomass': None,
#    'solar': 0.069},
#   'storage': {'battery': None, 'hydro': 0.0},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 1, 1, 45, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 5187.0,
#    'gas': 0.1438,
#    'oil': 0,
#    'hydro': 235.7,
#    'wind': 592.2,
#    'biomass': None,
#    'solar': 0.069},
#   'storage': {'battery': None, 'hydro': 0.0},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 1, 1, 50, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 5161.0,
#    'gas': 0.1338,
#    'oil': 0,
#    'hydro': 239.9,
#    'wind': 579.1,
#    'biomass': None,
#    'solar': 0.069},
#   'storage': {'battery': None, 'hydro': 0.0},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 1, 1, 55, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 5095.0,
#    'gas': 0.1237,
#    'oil': 0,
#    'hydro': 238.9,
#    'wind': 568.6,
#    'biomass': None,
#    'solar': 0.069},
#   'storage': {'battery': None, 'hydro': 0.0},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 1, 2, 0, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 5072.0,
#    'gas': 0.1438,
#    'oil': 0,
#    'hydro': 236.9,
#    'wind': 569.6,
#    'biomass': None,
#    'solar': 0.068},
#   'storage': {'battery': None, 'hydro': 0.0},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 1, 2, 5, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 5064.0,
#    'gas': 0.1237,
#    'oil': 0,
#    'hydro': 242.9,
#    'wind': 578.4,
#    'biomass': None,
#    'solar': 0.068},
#   'storage': {'battery': None, 'hydro': 0.0},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 1, 2, 10, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 5078.0,
#    'gas': 0.1237,
#    'oil': 0,
#    'hydro': 240.6,
#    'wind': 590.5,
#    'biomass': None,
#    'solar': 0.0},
#   'storage': {'battery': None, 'hydro': 0.0},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 1, 2, 15, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 5018.0,
#    'gas': 0.1539,
#    'oil': 0,
#    'hydro': 253.7,
#    'wind': 614.7,
#    'biomass': None,
#    'solar': 0.0},
#   'storage': {'battery': None, 'hydro': 0.0},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 1, 2, 20, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 4949.0,
#    'gas': 0.1237,
#    'oil': 0,
#    'hydro': 237.6,
#    'wind': 604.1,
#    'biomass': None,
#    'solar': 0.0},
#   'storage': {'battery': None, 'hydro': 0.0},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 1, 2, 25, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 4884.0,
#    'gas': 0.1237,
#    'oil': 0,
#    'hydro': 238.4,
#    'wind': 606.0,
#    'biomass': None,
#    'solar': 0.0},
#   'storage': {'battery': None, 'hydro': 0.0},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 1, 2, 30, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 4781.0,
#    'gas': 0.1237,
#    'oil': 0,
#    'hydro': 233.4,
#    'wind': 617.4,
#    'biomass': None,
#    'solar': 0.0},
#   'storage': {'battery': None, 'hydro': 0.0},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 1, 2, 35, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 4744.0,
#    'gas': 0.1237,
#    'oil': 0,
#    'hydro': 232.9,
#    'wind': 606.7,
#    'biomass': None,
#    'solar': 0.0},
#   'storage': {'battery': None, 'hydro': 0.0},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 1, 2, 40, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 4752.0,
#    'gas': 0.1438,
#    'oil': 0,
#    'hydro': 113.3,
#    'wind': 592.0,
#    'biomass': None,
#    'solar': 0.0},
#   'storage': {'battery': None, 'hydro': 0.0},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 1, 2, 45, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 4707.0,
#    'gas': 0.1338,
#    'oil': 0,
#    'hydro': 115.4,
#    'wind': 597.9,
#    'biomass': None,
#    'solar': 1e-05},
#   'storage': {'battery': None, 'hydro': 0.0},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 1, 2, 50, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 4715.0,
#    'gas': 0.1237,
#    'oil': 0,
#    'hydro': 115.7,
#    'wind': 619.3,
#    'biomass': None,
#    'solar': 1e-05},
#   'storage': {'battery': None, 'hydro': 0.0},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 1, 2, 55, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 4724.0,
#    'gas': 0.1338,
#    'oil': 0,
#    'hydro': 115.4,
#    'wind': 599.5,
#    'biomass': None,
#    'solar': 1e-05},
#   'storage': {'battery': None, 'hydro': 0.0},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 1, 3, 0, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 4715.0,
#    'gas': 0.1338,
#    'oil': 0,
#    'hydro': 115.0,
#    'wind': 599.0,
#    'biomass': None,
#    'solar': 1e-05},
#   'storage': {'battery': None, 'hydro': 0.0},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 1, 3, 5, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 4704.0,
#    'gas': 0.1237,
#    'oil': 0,
#    'hydro': 114.7,
#    'wind': 595.4,
#    'biomass': None,
#    'solar': 1e-05},
#   'storage': {'battery': None, 'hydro': 0.0},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 1, 3, 10, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 4625.0,
#    'gas': 0.1438,
#    'oil': 0,
#    'hydro': 113.5,
#    'wind': 610.1,
#    'biomass': None,
#    'solar': 1e-05},
#   'storage': {'battery': None, 'hydro': 0.0},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 1, 3, 15, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 4559.0,
#    'gas': 0.1237,
#    'oil': 0,
#    'hydro': 115.0,
#    'wind': 641.1,
#    'biomass': None,
#    'solar': 1e-05},
#   'storage': {'battery': None, 'hydro': 0.0},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 1, 3, 20, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 4486.0,
#    'gas': 0.08352,
#    'oil': 0,
#    'hydro': 115.4,
#    'wind': 663.7,
#    'biomass': None,
#    'solar': 1e-05},
#   'storage': {'battery': None, 'hydro': 0.0},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 1, 3, 25, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 4414.0,
#    'gas': 0.1438,
#    'oil': 0,
#    'hydro': 114.4,
#    'wind': 686.2,
#    'biomass': None,
#    'solar': 1e-05},
#   'storage': {'battery': None, 'hydro': 0.0},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 1, 3, 30, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 4432.0,
#    'gas': 0.1237,
#    'oil': 0,
#    'hydro': 115.6,
#    'wind': 688.4,
#    'biomass': None,
#    'solar': 0.066},
#   'storage': {'battery': None, 'hydro': 0.0},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 1, 3, 35, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 4400.0,
#    'gas': 0.08352,
#    'oil': 0,
#    'hydro': 115.5,
#    'wind': 678.7,
#    'biomass': None,
#    'solar': 0.066},
#   'storage': {'battery': None, 'hydro': 0.0},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 1, 3, 40, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 4369.0,
#    'gas': 0.1438,
#    'oil': 0,
#    'hydro': 115.7,
#    'wind': 667.3,
#    'biomass': None,
#    'solar': 0.066},
#   'storage': {'battery': None, 'hydro': 0.0},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 1, 3, 45, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 4419.0,
#    'gas': 0.1237,
#    'oil': 0,
#    'hydro': 116.0,
#    'wind': 649.5,
#    'biomass': None,
#    'solar': 0.066},
#   'storage': {'battery': None, 'hydro': 79.21},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 1, 3, 50, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 4445.0,
#    'gas': 0.1237,
#    'oil': 0,
#    'hydro': 115.4,
#    'wind': 627.0,
#    'biomass': None,
#    'solar': 0.066},
#   'storage': {'battery': None, 'hydro': 79.11},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 1, 3, 55, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 4473.0,
#    'gas': 0.1539,
#    'oil': 0,
#    'hydro': 115.3,
#    'wind': 609.3,
#    'biomass': None,
#    'solar': 0.066},
#   'storage': {'battery': None, 'hydro': 79.21},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 1, 4, 0, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 4482.0,
#    'gas': 0.1237,
#    'oil': 0,
#    'hydro': 115.4,
#    'wind': 619.9,
#    'biomass': None,
#    'solar': 0.066},
#   'storage': {'battery': None, 'hydro': 79.21},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 1, 4, 5, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 4529.0,
#    'gas': 0.1237,
#    'oil': 0,
#    'hydro': 115.6,
#    'wind': 632.1,
#    'biomass': None,
#    'solar': 0.066},
#   'storage': {'battery': None, 'hydro': 79.11},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 1, 4, 10, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 4603.0,
#    'gas': 0.1438,
#    'oil': 0,
#    'hydro': 115.0,
#    'wind': 630.8,
#    'biomass': None,
#    'solar': 0.066},
#   'storage': {'battery': None, 'hydro': 79.11},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 1, 4, 15, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 4596.0,
#    'gas': 0.1338,
#    'oil': 0,
#    'hydro': 114.2,
#    'wind': 622.6,
#    'biomass': None,
#    'solar': 0.066},
#   'storage': {'battery': None, 'hydro': 79.52},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 1, 4, 20, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 4674.0,
#    'gas': 0.1237,
#    'oil': 0,
#    'hydro': 115.7,
#    'wind': 608.5,
#    'biomass': None,
#    'solar': 0.066},
#   'storage': {'battery': None, 'hydro': 79.11},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 1, 4, 25, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 4684.0,
#    'gas': 0.1338,
#    'oil': 0,
#    'hydro': 115.5,
#    'wind': 584.4,
#    'biomass': None,
#    'solar': 0.066},
#   'storage': {'battery': None, 'hydro': 79.41},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 1, 4, 30, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 4698.0,
#    'gas': 0.08352,
#    'oil': 0,
#    'hydro': 115.1,
#    'wind': 577.4,
#    'biomass': None,
#    'solar': 0.066},
#   'storage': {'battery': None, 'hydro': 79.31},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 1, 4, 35, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 4671.0,
#    'gas': 0.1237,
#    'oil': 0,
#    'hydro': 114.4,
#    'wind': 580.7,
#    'biomass': None,
#    'solar': 0.066},
#   'storage': {'battery': None, 'hydro': 79.41},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 1, 4, 40, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 4715.0,
#    'gas': 0.1338,
#    'oil': 0,
#    'hydro': 115.8,
#    'wind': 573.6,
#    'biomass': None,
#    'solar': 0.066},
#   'storage': {'battery': None, 'hydro': 79.21},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 1, 4, 45, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 4681.0,
#    'gas': 0.1237,
#    'oil': 0,
#    'hydro': 115.5,
#    'wind': 571.2,
#    'biomass': None,
#    'solar': 0.066},
#   'storage': {'battery': None, 'hydro': 79.52},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 1, 4, 50, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 4764.0,
#    'gas': 0.1237,
#    'oil': 0,
#    'hydro': 115.4,
#    'wind': 563.8,
#    'biomass': None,
#    'solar': 0.066},
#   'storage': {'battery': None, 'hydro': 79.21},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 1, 4, 55, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 4813.0,
#    'gas': 0.1338,
#    'oil': 0,
#    'hydro': 126.1,
#    'wind': 540.9,
#    'biomass': None,
#    'solar': 0.066},
#   'storage': {'battery': None, 'hydro': 79.41},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 1, 5, 0, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 4812.0,
#    'gas': 0.1237,
#    'oil': 0,
#    'hydro': 237.7,
#    'wind': 564.2,
#    'biomass': None,
#    'solar': 0.066},
#   'storage': {'battery': None, 'hydro': 79.52},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 1, 5, 5, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 4845.0,
#    'gas': 0.1237,
#    'oil': 0,
#    'hydro': 270.6,
#    'wind': 567.7,
#    'biomass': None,
#    'solar': 0.066},
#   'storage': {'battery': None, 'hydro': 79.52},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 1, 5, 10, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 4931.0,
#    'gas': 0.1338,
#    'oil': 0,
#    'hydro': 242.8,
#    'wind': 561.5,
#    'biomass': None,
#    'solar': 0.066},
#   'storage': {'battery': None, 'hydro': 79.11},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 1, 5, 15, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 4968.0,
#    'gas': 0.1237,
#    'oil': 0,
#    'hydro': 240.5,
#    'wind': 554.1,
#    'biomass': None,
#    'solar': 0.066},
#   'storage': {'battery': None, 'hydro': 79.21},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 1, 5, 20, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 4976.0,
#    'gas': 0.1237,
#    'oil': 0,
#    'hydro': 241.5,
#    'wind': 566.4,
#    'biomass': None,
#    'solar': 0.066},
#   'storage': {'battery': None, 'hydro': 79.31},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 1, 5, 25, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 4956.0,
#    'gas': 0.1237,
#    'oil': 0,
#    'hydro': 231.3,
#    'wind': 559.0,
#    'biomass': None,
#    'solar': 0.066},
#   'storage': {'battery': None, 'hydro': 79.62},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 1, 5, 30, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 5007.0,
#    'gas': 0.04333,
#    'oil': 0,
#    'hydro': 238.4,
#    'wind': 552.2,
#    'biomass': None,
#    'solar': 0.066},
#   'storage': {'battery': None, 'hydro': 79.21},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 1, 5, 35, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 5009.0,
#    'gas': 0.1237,
#    'oil': 0,
#    'hydro': 239.3,
#    'wind': 551.8,
#    'biomass': None,
#    'solar': 0.066},
#   'storage': {'battery': None, 'hydro': 79.41},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 1, 5, 40, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 4981.0,
#    'gas': 0.08352,
#    'oil': 0,
#    'hydro': 254.8,
#    'wind': 552.6,
#    'biomass': None,
#    'solar': 0.066},
#   'storage': {'battery': None, 'hydro': 79.11},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 1, 5, 45, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 4919.0,
#    'gas': 0.00565,
#    'oil': 0,
#    'hydro': 256.2,
#    'wind': 555.5,
#    'biomass': None,
#    'solar': 0.066},
#   'storage': {'battery': None, 'hydro': 79.11},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 1, 5, 50, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 4887.0,
#    'gas': 0.08352,
#    'oil': 0,
#    'hydro': 249.2,
#    'wind': 551.3,
#    'biomass': None,
#    'solar': 0.266},
#   'storage': {'battery': None, 'hydro': 79.21},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 1, 5, 55, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 4850.0,
#    'gas': 0.00565,
#    'oil': 0,
#    'hydro': 256.6,
#    'wind': 568.3,
#    'biomass': None,
#    'solar': 0.256},
#   'storage': {'battery': None, 'hydro': 79.21},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 1, 6, 0, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 4794.0,
#    'gas': 0.1237,
#    'oil': 0,
#    'hydro': 255.6,
#    'wind': 572.6,
#    'biomass': None,
#    'solar': 4.947},
#   'storage': {'battery': None, 'hydro': 79.11},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 1, 6, 5, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 4773.0,
#    'gas': 0.1438,
#    'oil': 0,
#    'hydro': 259.3,
#    'wind': 570.4,
#    'biomass': None,
#    'solar': 11.66},
#   'storage': {'battery': None, 'hydro': 79.11},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 1, 6, 10, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 4924.0,
#    'gas': 0.00565,
#    'oil': 0,
#    'hydro': 249.5,
#    'wind': 561.5,
#    'biomass': None,
#    'solar': 19.35},
#   'storage': {'battery': None, 'hydro': 78.8},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 1, 6, 15, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 5072.0,
#    'gas': 0.08352,
#    'oil': 0,
#    'hydro': 118.7,
#    'wind': 550.3,
#    'biomass': None,
#    'solar': 35.32},
#   'storage': {'battery': None, 'hydro': 79.01},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 1, 6, 20, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 5064.0,
#    'gas': 0.1338,
#    'oil': 0,
#    'hydro': 114.2,
#    'wind': 567.8,
#    'biomass': None,
#    'solar': 54.17},
#   'storage': {'battery': None, 'hydro': 79.21},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 1, 6, 25, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 5097.0,
#    'gas': 0.04333,
#    'oil': 0,
#    'hydro': 115.6,
#    'wind': 567.6,
#    'biomass': None,
#    'solar': 79.15},
#   'storage': {'battery': None, 'hydro': 79.11},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 1, 6, 30, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 5030.0,
#    'gas': 0.1237,
#    'oil': 0,
#    'hydro': 114.6,
#    'wind': 566.6,
#    'biomass': None,
#    'solar': 127.1},
#   'storage': {'battery': None, 'hydro': 79.41},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 1, 6, 35, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 5080.0,
#    'gas': 0.1237,
#    'oil': 0,
#    'hydro': 115.4,
#    'wind': 571.3,
#    'biomass': None,
#    'solar': 144.5},
#   'storage': {'battery': None, 'hydro': 79.31},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 1, 6, 40, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 5074.0,
#    'gas': 0.08352,
#    'oil': 0,
#    'hydro': 115.0,
#    'wind': 560.5,
#    'biomass': None,
#    'solar': 184.6},
#   'storage': {'battery': None, 'hydro': 79.21},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 1, 6, 45, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 5001.0,
#    'gas': 0.1237,
#    'oil': 0,
#    'hydro': 115.3,
#    'wind': 551.5,
#    'biomass': None,
#    'solar': 259.0},
#   'storage': {'battery': None, 'hydro': 79.01},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 1, 6, 50, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 4930.0,
#    'gas': 0.1237,
#    'oil': 0,
#    'hydro': 115.0,
#    'wind': 545.3,
#    'biomass': None,
#    'solar': 356.5},
#   'storage': {'battery': None, 'hydro': 79.21},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 1, 6, 55, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 4839.0,
#    'gas': 0.04333,
#    'oil': 0,
#    'hydro': 115.4,
#    'wind': 529.8,
#    'biomass': None,
#    'solar': 385.7},
#   'storage': {'battery': None, 'hydro': 79.11},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 1, 7, 0, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 4915.0,
#    'gas': 0.08352,
#    'oil': 0,
#    'hydro': 115.6,
#    'wind': 531.4,
#    'biomass': None,
#    'solar': 526.9},
#   'storage': {'battery': None, 'hydro': 79.01},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 1, 7, 5, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 4915.0,
#    'gas': 0.1438,
#    'oil': 0,
#    'hydro': 115.1,
#    'wind': 534.3,
#    'biomass': None,
#    'solar': 544.2},
#   'storage': {'battery': None, 'hydro': 78.9},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 1, 7, 10, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 4876.0,
#    'gas': 0.08352,
#    'oil': 0,
#    'hydro': 115.4,
#    'wind': 554.0,
#    'biomass': None,
#    'solar': 586.9},
#   'storage': {'battery': None, 'hydro': 79.01},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 1, 7, 15, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 4952.0,
#    'gas': 0.08352,
#    'oil': 0,
#    'hydro': 115.6,
#    'wind': 535.5,
#    'biomass': None,
#    'solar': 600.2},
#   'storage': {'battery': None, 'hydro': 79.01},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 1, 7, 20, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 4983.0,
#    'gas': 0.08352,
#    'oil': 0,
#    'hydro': 115.4,
#    'wind': 543.1,
#    'biomass': None,
#    'solar': 516.0},
#   'storage': {'battery': None, 'hydro': 79.11},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 1, 7, 25, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 4949.0,
#    'gas': 0.08352,
#    'oil': 0,
#    'hydro': 114.9,
#    'wind': 563.2,
#    'biomass': None,
#    'solar': 631.8},
#   'storage': {'battery': None, 'hydro': 79.01},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 1, 7, 30, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 4943.0,
#    'gas': 0.08352,
#    'oil': 0,
#    'hydro': 115.2,
#    'wind': 576.0,
#    'biomass': None,
# ...
#   'production': {'coal': 3060.0,
#    'gas': 0.08352,
#    'oil': 0,
#    'hydro': 49.89,
#    'wind': 779.5,
#    'biomass': None,
#    'solar': 1121.0},
#   'storage': {'battery': None, 'hydro': 314.1},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 4, 8, 55, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 3088.0,
#    'gas': 0.08352,
#    'oil': 0,
#    'hydro': 50.74,
#    'wind': 809.9,
#    'biomass': None,
#    'solar': 1102.0},
#   'storage': {'battery': None, 'hydro': 314.1},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 4, 9, 0, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 3040.0,
#    'gas': 0.08352,
#    'oil': 0,
#    'hydro': 50.36,
#    'wind': 824.0,
#    'biomass': None,
#    'solar': 1140.0},
#   'storage': {'battery': None, 'hydro': 313.9},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 4, 9, 5, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 3005.0,
#    'gas': 0.00565,
#    'oil': 0,
#    'hydro': 50.95,
#    'wind': 826.7,
#    'biomass': None,
#    'solar': 1175.0},
#   'storage': {'battery': None, 'hydro': 315.6},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 4, 9, 10, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 3013.0,
#    'gas': 0.1237,
#    'oil': 0,
#    'hydro': 50.59,
#    'wind': 851.4,
#    'biomass': None,
#    'solar': 1129.0},
#   'storage': {'battery': None, 'hydro': 410.8},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 4, 9, 15, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 3017.0,
#    'gas': 0.1237,
#    'oil': 0,
#    'hydro': 50.39,
#    'wind': 870.8,
#    'biomass': None,
#    'solar': 1140.0},
#   'storage': {'battery': None, 'hydro': 503.0},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 4, 9, 20, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 3200.0,
#    'gas': 0.1237,
#    'oil': 0,
#    'hydro': 228.7,
#    'wind': 888.0,
#    'biomass': None,
#    'solar': 1137.0},
#   'storage': {'battery': None, 'hydro': 506.2},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 4, 9, 25, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 3258.0,
#    'gas': 0.00565,
#    'oil': 0,
#    'hydro': 219.6,
#    'wind': 867.5,
#    'biomass': None,
#    'solar': 1215.0},
#   'storage': {'battery': None, 'hydro': 506.9},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 4, 9, 30, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 3382.0,
#    'gas': 0.1237,
#    'oil': 0,
#    'hydro': 219.3,
#    'wind': 867.5,
#    'biomass': None,
#    'solar': 1244.0},
#   'storage': {'battery': None, 'hydro': 506.0},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 4, 9, 35, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 3414.0,
#    'gas': 0.1237,
#    'oil': 0,
#    'hydro': 221.8,
#    'wind': 856.6,
#    'biomass': None,
#    'solar': 1249.0},
#   'storage': {'battery': None, 'hydro': 506.8},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 4, 9, 40, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 3377.0,
#    'gas': 0.00565,
#    'oil': 0,
#    'hydro': 199.3,
#    'wind': 868.9,
#    'biomass': None,
#    'solar': 1265.0},
#   'storage': {'battery': None, 'hydro': 506.6},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 4, 9, 45, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 3219.0,
#    'gas': 0.08352,
#    'oil': 0,
#    'hydro': 165.0,
#    'wind': 882.7,
#    'biomass': None,
#    'solar': 1383.0},
#   'storage': {'battery': None, 'hydro': 508.6},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 4, 9, 50, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 3162.0,
#    'gas': 0.1237,
#    'oil': 0,
#    'hydro': 51.39,
#    'wind': 879.6,
#    'biomass': None,
#    'solar': 1271.0},
#   'storage': {'battery': None, 'hydro': 506.9},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 4, 9, 55, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 3089.0,
#    'gas': 0.1237,
#    'oil': 0,
#    'hydro': 51.06,
#    'wind': 924.8,
#    'biomass': None,
#    'solar': 1194.0},
#   'storage': {'battery': None, 'hydro': 505.4},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 4, 10, 0, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 3090.0,
#    'gas': 0.08352,
#    'oil': 0,
#    'hydro': 50.39,
#    'wind': 951.8,
#    'biomass': None,
#    'solar': 1064.0},
#   'storage': {'battery': None, 'hydro': 506.4},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 4, 10, 5, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 3052.0,
#    'gas': 0.08352,
#    'oil': 0,
#    'hydro': 50.62,
#    'wind': 973.5,
#    'biomass': None,
#    'solar': 1094.0},
#   'storage': {'battery': None, 'hydro': 506.6},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 4, 10, 10, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 3070.0,
#    'gas': 0.1237,
#    'oil': 0,
#    'hydro': 50.68,
#    'wind': 952.3,
#    'biomass': None,
#    'solar': 1115.0},
#   'storage': {'battery': None, 'hydro': 605.3},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 4, 10, 15, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 3025.0,
#    'gas': 0.00565,
#    'oil': 0,
#    'hydro': 3.559,
#    'wind': 966.0,
#    'biomass': None,
#    'solar': 1208.0},
#   'storage': {'battery': None, 'hydro': 700.3},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 4, 10, 20, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 2951.0,
#    'gas': 0.08352,
#    'oil': 0,
#    'hydro': 3.884,
#    'wind': 981.3,
#    'biomass': None,
#    'solar': 1218.0},
#   'storage': {'battery': None, 'hydro': 706.8},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 4, 10, 25, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 3022.0,
#    'gas': 0.1338,
#    'oil': 0,
#    'hydro': 3.856,
#    'wind': 995.3,
#    'biomass': None,
#    'solar': 1036.0},
#   'storage': {'battery': None, 'hydro': 703.0},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 4, 10, 30, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 2946.0,
#    'gas': 0.1237,
#    'oil': 0,
#    'hydro': 3.298,
#    'wind': 967.0,
#    'biomass': None,
#    'solar': 1037.0},
#   'storage': {'battery': None, 'hydro': 706.4},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 4, 10, 35, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 2935.0,
#    'gas': 0.00565,
#    'oil': 0,
#    'hydro': 3.941,
#    'wind': 996.6,
#    'biomass': None,
#    'solar': 1045.0},
#   'storage': {'battery': None, 'hydro': 706.2},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 4, 10, 40, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 2980.0,
#    'gas': 0.1237,
#    'oil': 0,
#    'hydro': 3.941,
#    'wind': 1116.0,
#    'biomass': None,
#    'solar': 1132.0},
#   'storage': {'battery': None, 'hydro': 705.8},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 4, 10, 45, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 2936.0,
#    'gas': 0.1438,
#    'oil': 0,
#    'hydro': 3.884,
#    'wind': 1086.0,
#    'biomass': None,
#    'solar': 907.0},
#   'storage': {'battery': None, 'hydro': 704.9},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 4, 10, 50, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 2948.0,
#    'gas': 0.08352,
#    'oil': 0,
#    'hydro': 4.089,
#    'wind': 1121.0,
#    'biomass': None,
#    'solar': 934.4},
#   'storage': {'battery': None, 'hydro': 706.0},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 4, 10, 55, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 3063.0,
#    'gas': 0.04333,
#    'oil': 0,
#    'hydro': 4.089,
#    'wind': 1139.0,
#    'biomass': None,
#    'solar': 742.7},
#   'storage': {'battery': None, 'hydro': 701.7},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 4, 11, 0, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 2986.0,
#    'gas': 0.08352,
#    'oil': 0,
#    'hydro': 4.089,
#    'wind': 1148.0,
#    'biomass': None,
#    'solar': 730.0},
#   'storage': {'battery': None, 'hydro': 703.0},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 4, 11, 5, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 2895.0,
#    'gas': 0.1237,
#    'oil': 0,
#    'hydro': 3.972,
#    'wind': 1162.0,
#    'biomass': None,
#    'solar': 828.7},
#   'storage': {'battery': None, 'hydro': 706.3},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 4, 11, 10, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 2893.0,
#    'gas': 0.08352,
#    'oil': 0,
#    'hydro': 4.149,
#    'wind': 1127.0,
#    'biomass': None,
#    'solar': 768.1},
#   'storage': {'battery': None, 'hydro': 706.4},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 4, 11, 15, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 2934.0,
#    'gas': 0.08352,
#    'oil': 0,
#    'hydro': 3.767,
#    'wind': 1143.0,
#    'biomass': None,
#    'solar': 829.7},
#   'storage': {'battery': None, 'hydro': 705.0},
#   'capacity': {'coal': 11990.0,
#    'gas': 1867.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': 840.0,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  ...]

# %%
result_all = fetch_production('AUS-NSW')
# Out:
# Setting small value of oil (-0.06376) to 0.
# Setting small value of oil (-0.06376) to 0.
# Setting small value of oil (-0.06376) to 0.
# Setting small value of oil (-0.06376) to 0.
# Setting small value of oil (-0.06376) to 0.
# Setting small value of oil (-0.06376) to 0.
# Setting small value of oil (-0.06659) to 0.
# Setting small value of oil (-0.06659) to 0.
# Setting small value of oil (-0.06659) to 0.
# Setting small value of oil (-0.06659) to 0.
# Setting small value of oil (-0.06659) to 0.
# Setting small value of oil (-0.06659) to 0.
# Setting small value of oil (-0.06659) to 0.
# Setting small value of oil (-0.06659) to 0.
# Setting small value of oil (-0.06659) to 0.
# Setting small value of oil (-0.06668) to 0.
# Setting small value of oil (-0.06668) to 0.
# Setting small value of oil (-0.06668) to 0.
# Setting small value of oil (-0.06668) to 0.
# Setting small value of oil (-0.06668) to 0.
# Setting small value of oil (-0.06668) to 0.
# Setting small value of oil (-0.06668) to 0.
# Setting small value of oil (-0.06668) to 0.
# Setting small value of oil (-0.06668) to 0.
# Setting small value of oil (-0.06827) to 0.
# Setting small value of oil (-0.06827) to 0.
# Setting small value of oil (-0.06827) to 0.
# Setting small value of oil (-0.06827) to 0.
# Setting small value of oil (-0.06827) to 0.
# Setting small value of oil (-0.06827) to 0.
# Setting small value of oil (-0.06827) to 0.
# Setting small value of oil (-0.06827) to 0.
# Setting small value of oil (-0.06827) to 0.
# Setting small value of oil (-0.06712) to 0.
# Setting small value of oil (-0.06712) to 0.
# Setting small value of oil (-0.06712) to 0.
# Setting small value of oil (-0.06712) to 0.
# Setting small value of oil (-0.06712) to 0.
# Setting small value of oil (-0.06712) to 0.
# Setting small value of oil (-0.06712) to 0.
# Setting small value of oil (-0.06712) to 0.
# Setting small value of oil (-0.06712) to 0.
# Setting small value of oil (-0.06924) to 0.
# Setting small value of oil (-0.06924) to 0.
# Setting small value of oil (-0.06924) to 0.
# Setting small value of oil (-0.06924) to 0.
# Setting small value of oil (-0.06924) to 0.
# Setting small value of oil (-0.06924) to 0.
# Setting small value of oil (-0.06924) to 0.
# Setting small value of oil (-0.06924) to 0.
# Setting small value of oil (-0.06924) to 0.
# Setting small value of oil (-0.07111) to 0.
# Setting small value of oil (-0.07111) to 0.
# Setting small value of oil (-0.07111) to 0.
# Setting small value of oil (-0.07111) to 0.
# Setting small value of oil (-0.07111) to 0.
# Setting small value of oil (-0.07111) to 0.
# Setting small value of oil (-0.07111) to 0.
# Setting small value of oil (-0.07111) to 0.
# Setting small value of oil (-0.07111) to 0.
# Setting small value of oil (-0.06818) to 0.
# Setting small value of oil (-0.06818) to 0.
# Setting small value of oil (-0.06818) to 0.
# Setting small value of oil (-0.06818) to 0.
# Setting small value of oil (-0.06818) to 0.
# Setting small value of oil (-0.06818) to 0.
# Setting small value of oil (-0.06818) to 0.
# Setting small value of oil (-0.06818) to 0.
# Setting small value of oil (-0.06818) to 0.
# Setting small value of oil (-0.06605) to 0.
# Setting small value of oil (-0.06605) to 0.
# Setting small value of oil (-0.06605) to 0.
# Setting small value of oil (-0.06605) to 0.
# Setting small value of oil (-0.06605) to 0.
# Setting small value of oil (-0.06605) to 0.
# Setting small value of oil (-0.06605) to 0.
# Setting small value of oil (-0.06605) to 0.
# Setting small value of oil (-0.06605) to 0.
# Setting small value of oil (-0.07028) to 0.
# Setting small value of oil (-0.07028) to 0.
# Setting small value of oil (-0.07028) to 0.
# Setting small value of oil (-0.07028) to 0.
# Setting small value of oil (-0.07028) to 0.
# Setting small value of oil (-0.07028) to 0.
# Setting small value of oil (-0.07028) to 0.
# Setting small value of oil (-0.07028) to 0.
# Setting small value of oil (-0.07028) to 0.
# Setting small value of oil (-0.07271) to 0.
# Setting small value of oil (-0.07271) to 0.
# Setting small value of oil (-0.07271) to 0.
# Setting small value of oil (-0.07271) to 0.
# Setting small value of oil (-0.07271) to 0.
# Setting small value of oil (-0.07271) to 0.
# Setting small value of oil (-0.07271) to 0.
# Setting small value of oil (-0.07271) to 0.
# Setting small value of oil (-0.07271) to 0.
# Setting small value of oil (-0.06861) to 0.
# Setting small value of oil (-0.06861) to 0.
# Setting small value of oil (-0.06861) to 0.
# Setting small value of oil (-0.06861) to 0.
# Setting small value of oil (-0.06861) to 0.
# Setting small value of oil (-0.06861) to 0.
# Setting small value of oil (-0.06861) to 0.
# Setting small value of oil (-0.06861) to 0.
# Setting small value of oil (-0.06861) to 0.
# Setting small value of oil (-0.06891) to 0.
# Setting small value of oil (-0.06891) to 0.
# Setting small value of oil (-0.06891) to 0.
# Setting small value of oil (-0.06891) to 0.
# Setting small value of oil (-0.06891) to 0.
# Setting small value of oil (-0.06891) to 0.
# Setting small value of oil (-0.06891) to 0.
# Setting small value of oil (-0.06891) to 0.
# Setting small value of oil (-0.06891) to 0.
# Setting small value of oil (-0.06558) to 0.
# Setting small value of oil (-0.06558) to 0.
# Setting small value of oil (-0.06558) to 0.
# Setting small value of oil (-0.06558) to 0.
# Setting small value of oil (-0.06558) to 0.
# Setting small value of oil (-0.06558) to 0.
# Setting small value of oil (-0.06558) to 0.
# Setting small value of oil (-0.06558) to 0.
# Setting small value of oil (-0.06558) to 0.
# Setting small value of oil (-0.07011) to 0.
# Setting small value of oil (-0.07011) to 0.
# Setting small value of oil (-0.07011) to 0.
# Setting small value of oil (-0.07011) to 0.
# Setting small value of oil (-0.07011) to 0.
# Setting small value of oil (-0.07011) to 0.
# Setting small value of oil (-0.07011) to 0.
# Setting small value of oil (-0.07011) to 0.
# Setting small value of oil (-0.07011) to 0.
# Setting small value of oil (-0.06669) to 0.
# Setting small value of oil (-0.06669) to 0.
# Setting small value of oil (-0.06669) to 0.
# Setting small value of oil (-0.06669) to 0.
# Setting small value of oil (-0.06669) to 0.
# Setting small value of oil (-0.06669) to 0.
# Setting small value of oil (-0.06669) to 0.
# Setting small value of oil (-0.06669) to 0.
# Setting small value of oil (-0.06669) to 0.
# Setting small value of oil (-0.07503) to 0.
# Setting small value of oil (-0.07503) to 0.
# Setting small value of oil (-0.07503) to 0.
# Setting small value of oil (-0.07503) to 0.
# Setting small value of oil (-0.07503) to 0.
# Setting small value of oil (-0.07503) to 0.
# Setting small value of oil (-0.07503) to 0.
# Setting small value of oil (-0.07503) to 0.
# Setting small value of oil (-0.07503) to 0.
# Setting small value of oil (-0.06985) to 0.
# Setting small value of oil (-0.06985) to 0.
# Setting small value of oil (-0.06985) to 0.
# Setting small value of oil (-0.06985) to 0.
# Setting small value of oil (-0.06985) to 0.
# Setting small value of oil (-0.06985) to 0.
# Setting small value of oil (-0.06985) to 0.
# Setting small value of oil (-0.06985) to 0.
# Setting small value of oil (-0.06985) to 0.
# Setting small value of oil (-0.07034) to 0.
# Setting small value of oil (-0.07034) to 0.
# Setting small value of oil (-0.07034) to 0.
# Setting small value of oil (-0.07034) to 0.
# Setting small value of oil (-0.07034) to 0.
# Setting small value of oil (-0.07034) to 0.
# Setting small value of oil (-0.07034) to 0.
# Setting small value of oil (-0.07034) to 0.
# Setting small value of oil (-0.07034) to 0.
# Setting small value of oil (-0.07213) to 0.
# Setting small value of oil (-0.07213) to 0.
# Setting small value of oil (-0.07213) to 0.
# Setting small value of oil (-0.07213) to 0.
# Setting small value of oil (-0.07213) to 0.
# Setting small value of oil (-0.07213) to 0.
# Setting small value of oil (-0.07213) to 0.
# Setting small value of oil (-0.07213) to 0.
# Setting small value of oil (-0.07213) to 0.
# Setting small value of oil (-0.07272) to 0.
# Setting small value of oil (-0.07272) to 0.
# Setting small value of oil (-0.07272) to 0.
# Setting small value of oil (-0.07272) to 0.
# Setting small value of oil (-0.07272) to 0.
# Setting small value of oil (-0.07272) to 0.
# Setting small value of oil (-0.07272) to 0.
# Setting small value of oil (-0.07272) to 0.
# Setting small value of oil (-0.07272) to 0.
# Setting small value of oil (-0.06895) to 0.
# Setting small value of oil (-0.06895) to 0.
# Setting small value of oil (-0.06895) to 0.
# Setting small value of oil (-0.06895) to 0.
# Setting small value of oil (-0.06895) to 0.
# Setting small value of oil (-0.06895) to 0.
# Setting small value of oil (-0.06895) to 0.
# Setting small value of oil (-0.06895) to 0.
# Setting small value of oil (-0.06895) to 0.
# Setting small value of oil (-0.07268) to 0.
# Setting small value of oil (-0.07268) to 0.
# Setting small value of oil (-0.07268) to 0.
# Setting small value of oil (-0.07268) to 0.
# Setting small value of oil (-0.07268) to 0.
# Setting small value of oil (-0.07268) to 0.
# Setting small value of oil (-0.07268) to 0.
# Setting small value of oil (-0.07268) to 0.
# Setting small value of oil (-0.07268) to 0.
# Setting small value of oil (-0.07084) to 0.
# Setting small value of oil (-0.07084) to 0.
# Setting small value of oil (-0.07084) to 0.
# Setting small value of oil (-0.07084) to 0.
# Setting small value of oil (-0.07084) to 0.
# Setting small value of oil (-0.07084) to 0.
# Setting small value of oil (-0.07084) to 0.
# Setting small value of oil (-0.07084) to 0.
# Setting small value of oil (-0.07084) to 0.
# Setting small value of oil (-0.07576) to 0.
# Setting small value of oil (-0.07576) to 0.
# Setting small value of oil (-0.07576) to 0.
# Setting small value of oil (-0.07576) to 0.
# Setting small value of oil (-0.07576) to 0.
# Setting small value of oil (-0.07576) to 0.
# Setting small value of oil (-0.07576) to 0.
# Setting small value of oil (-0.07576) to 0.
# Setting small value of oil (-0.07576) to 0.
# Setting small value of oil (-0.07111) to 0.
# Setting small value of oil (-0.07111) to 0.
# Setting small value of oil (-0.07111) to 0.
# Setting small value of oil (-0.07111) to 0.
# Setting small value of oil (-0.07111) to 0.
# Setting small value of oil (-0.07111) to 0.
# Setting small value of oil (-0.07111) to 0.
# Setting small value of oil (-0.07111) to 0.
# Setting small value of oil (-0.07111) to 0.
# Setting small value of oil (-0.06783) to 0.
# Setting small value of oil (-0.06783) to 0.
# Setting small value of oil (-0.06783) to 0.
# Setting small value of oil (-0.06783) to 0.
# Setting small value of oil (-0.06783) to 0.
# Setting small value of oil (-0.06783) to 0.
# Setting small value of oil (-0.06783) to 0.
# Setting small value of oil (-0.06783) to 0.
# Setting small value of oil (-0.06783) to 0.
# Setting small value of oil (-0.0618) to 0.
# Setting small value of oil (-0.0618) to 0.
# Setting small value of oil (-0.0618) to 0.
# Setting small value of oil (-0.0618) to 0.
# Setting small value of oil (-0.0618) to 0.
# Setting small value of oil (-0.0618) to 0.
# Setting small value of oil (-0.0618) to 0.
# Setting small value of oil (-0.0618) to 0.
# Setting small value of oil (-0.0618) to 0.
# Setting small value of oil (-0.06355) to 0.
# Setting small value of oil (-0.06355) to 0.
# Setting small value of oil (-0.06355) to 0.
# Setting small value of oil (-0.06355) to 0.
# Setting small value of oil (-0.06355) to 0.
# Setting small value of oil (-0.06355) to 0.
# Setting small value of oil (-0.06355) to 0.
# Setting small value of oil (-0.06355) to 0.
# Setting small value of oil (-0.06355) to 0.
# Setting small value of oil (-0.06403) to 0.
# Setting small value of oil (-0.06403) to 0.
# Setting small value of oil (-0.06403) to 0.
# Setting small value of oil (-0.06403) to 0.
# Setting small value of oil (-0.06403) to 0.
# Setting small value of oil (-0.06403) to 0.
# Setting small value of oil (-0.06403) to 0.
# Setting small value of oil (-0.06403) to 0.
# Setting small value of oil (-0.06403) to 0.
# Setting small value of oil (-0.07026) to 0.
# Setting small value of oil (-0.07026) to 0.
# Setting small value of oil (-0.07026) to 0.
# Setting small value of oil (-0.07026) to 0.
# Setting small value of oil (-0.07026) to 0.
# Setting small value of oil (-0.07026) to 0.
# Setting small value of oil (-0.07026) to 0.
# Setting small value of oil (-0.07026) to 0.
# Setting small value of oil (-0.07026) to 0.
# Setting small value of oil (-0.07438) to 0.
# Setting small value of oil (-0.07438) to 0.
# Setting small value of oil (-0.07438) to 0.
# Setting small value of oil (-0.07438) to 0.
# Setting small value of oil (-0.07438) to 0.
# Setting small value of oil (-0.07438) to 0.
# Setting small value of oil (-0.07438) to 0.
# Setting small value of oil (-0.07438) to 0.
# Setting small value of oil (-0.07438) to 0.
# Setting small value of oil (-0.07626) to 0.
# Setting small value of oil (-0.07626) to 0.
# Setting small value of oil (-0.07626) to 0.
# Setting small value of oil (-0.07626) to 0.

# %%
result_all
# Out:
# [{'datetime': datetime.datetime(2021, 10, 12, 12, 55, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 5018.0,
#    'gas': 0.08352,
#    'oil': 0,
#    'hydro': 242.5,
#    'wind': 1245.0,
#    'biomass': None,
#    'solar': 949.8},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 12, 13, 0, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 4929.0,
#    'gas': 0.08352,
#    'oil': 0,
#    'hydro': 202.6,
#    'wind': 1247.0,
#    'biomass': None,
#    'solar': 994.6},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 12, 13, 5, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 4924.0,
#    'gas': 0.08352,
#    'oil': 0,
#    'hydro': 125.6,
#    'wind': 1226.0,
#    'biomass': None,
#    'solar': 940.5},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 12, 13, 10, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 4996.0,
#    'gas': 0.08352,
#    'oil': 0,
#    'hydro': 275.8,
#    'wind': 1199.0,
#    'biomass': None,
#    'solar': 945.5},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 12, 13, 15, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 5064.0,
#    'gas': 0.04333,
#    'oil': 0,
#    'hydro': 400.7,
#    'wind': 1201.0,
#    'biomass': None,
#    'solar': 1012.0},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 12, 13, 20, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 5201.0,
#    'gas': 0.1237,
#    'oil': 0,
#    'hydro': 502.7,
#    'wind': 1174.0,
#    'biomass': None,
#    'solar': 1037.0},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 12, 13, 25, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 5099.0,
#    'gas': 0.1237,
#    'oil': 0,
#    'hydro': 464.5,
#    'wind': 1150.0,
#    'biomass': None,
#    'solar': 1048.0},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 12, 13, 30, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 5203.0,
#    'gas': 0.04333,
#    'oil': 0,
#    'hydro': 492.9,
#    'wind': 1157.0,
#    'biomass': None,
#    'solar': 1031.0},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 12, 13, 35, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 5316.0,
#    'gas': 0.08352,
#    'oil': 0,
#    'hydro': 501.5,
#    'wind': 1159.0,
#    'biomass': None,
#    'solar': 949.2},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 12, 13, 40, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 5437.0,
#    'gas': 0.1438,
#    'oil': 0,
#    'hydro': 530.0,
#    'wind': 1149.0,
#    'biomass': None,
#    'solar': 932.4},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 12, 13, 45, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 5380.0,
#    'gas': 0.00565,
#    'oil': 0,
#    'hydro': 535.5,
#    'wind': 1162.0,
#    'biomass': None,
#    'solar': 915.9},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 12, 13, 50, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 5265.0,
#    'gas': 0.04333,
#    'oil': 0,
#    'hydro': 437.4,
#    'wind': 1175.0,
#    'biomass': None,
#    'solar': 910.6},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 12, 13, 55, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 5177.0,
#    'gas': 0.08352,
#    'oil': 0,
#    'hydro': 360.5,
#    'wind': 1157.0,
#    'biomass': None,
#    'solar': 806.5},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 12, 14, 0, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 5054.0,
#    'gas': 0.1237,
#    'oil': 0,
#    'hydro': 259.2,
#    'wind': 1162.0,
#    'biomass': None,
#    'solar': 741.6},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 12, 14, 5, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 5240.0,
#    'gas': 0.08352,
#    'oil': 0,
#    'hydro': 389.2,
#    'wind': 1154.0,
#    'biomass': None,
#    'solar': 751.2},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 12, 14, 10, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 5308.0,
#    'gas': 0.08352,
#    'oil': 0,
#    'hydro': 482.3,
#    'wind': 1179.0,
#    'biomass': None,
#    'solar': 793.4},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 12, 14, 15, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 5369.0,
#    'gas': 0.08352,
#    'oil': 0,
#    'hydro': 505.6,
#    'wind': 1215.0,
#    'biomass': None,
#    'solar': 829.5},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 12, 14, 20, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 5421.0,
#    'gas': 0.08352,
#    'oil': 0,
#    'hydro': 521.3,
#    'wind': 1226.0,
#    'biomass': None,
#    'solar': 844.0},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 12, 14, 25, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 5440.0,
#    'gas': 0.0,
#    'oil': 0,
#    'hydro': 514.4,
#    'wind': 1217.0,
#    'biomass': None,
#    'solar': 782.2},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 12, 14, 30, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 5445.0,
#    'gas': 0.0,
#    'oil': 0,
#    'hydro': 502.1,
#    'wind': 1210.0,
#    'biomass': None,
#    'solar': 766.0},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 12, 14, 35, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 5409.0,
#    'gas': 0.08352,
#    'oil': 0,
#    'hydro': 494.9,
#    'wind': 1192.0,
#    'biomass': None,
#    'solar': 818.0},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 12, 14, 40, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 5421.0,
#    'gas': 0.1237,
#    'oil': 0,
#    'hydro': 521.1,
#    'wind': 1230.0,
#    'biomass': None,
#    'solar': 802.4},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 12, 14, 45, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 5455.0,
#    'gas': 0.08352,
#    'oil': 0,
#    'hydro': 540.1,
#    'wind': 1262.0,
#    'biomass': None,
#    'solar': 757.6},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 12, 14, 50, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 5283.0,
#    'gas': 0.08352,
#    'oil': 0,
#    'hydro': 428.7,
#    'wind': 1261.0,
#    'biomass': None,
#    'solar': 740.4},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 12, 14, 55, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 5461.0,
#    'gas': 0.08352,
#    'oil': 0,
#    'hydro': 530.6,
#    'wind': 1212.0,
#    'biomass': None,
#    'solar': 705.9},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 12, 15, 0, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 5277.0,
#    'gas': 0.08352,
#    'oil': 0,
#    'hydro': 421.5,
#    'wind': 1227.0,
#    'biomass': None,
#    'solar': 664.4},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 12, 15, 5, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 5453.0,
#    'gas': 0.08352,
#    'oil': 0,
#    'hydro': 529.6,
#    'wind': 1221.0,
#    'biomass': None,
#    'solar': 704.5},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 12, 15, 10, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 5490.0,
#    'gas': 0.08352,
#    'oil': 0,
#    'hydro': 569.5,
#    'wind': 1184.0,
#    'biomass': None,
#    'solar': 845.7},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 12, 15, 15, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 5527.0,
#    'gas': 0.08352,
#    'oil': 0,
#    'hydro': 576.4,
#    'wind': 1203.0,
#    'biomass': None,
#    'solar': 783.4},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 12, 15, 20, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 5359.0,
#    'gas': 0.08352,
#    'oil': 0,
#    'hydro': 460.9,
#    'wind': 1208.0,
#    'biomass': None,
#    'solar': 724.8},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 12, 15, 25, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 5354.0,
#    'gas': 0.08352,
#    'oil': 0,
#    'hydro': 510.5,
#    'wind': 1263.0,
#    'biomass': None,
#    'solar': 709.8},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 12, 15, 30, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 5559.0,
#    'gas': 0.08352,
#    'oil': 0,
#    'hydro': 608.6,
#    'wind': 1228.0,
#    'biomass': None,
#    'solar': 700.1},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 12, 15, 35, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 5457.0,
#    'gas': 0.08352,
#    'oil': 0,
#    'hydro': 586.0,
#    'wind': 1205.0,
#    'biomass': None,
#    'solar': 741.0},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 12, 15, 40, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 5592.0,
#    'gas': 0.08352,
#    'oil': 0,
#    'hydro': 641.8,
#    'wind': 1196.0,
#    'biomass': None,
#    'solar': 757.2},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 12, 15, 45, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 5698.0,
#    'gas': 0.08352,
#    'oil': 0,
#    'hydro': 715.8,
#    'wind': 1201.0,
#    'biomass': None,
#    'solar': 743.8},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 12, 15, 50, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 5781.0,
#    'gas': 0.1237,
#    'oil': 0,
#    'hydro': 719.7,
#    'wind': 1189.0,
#    'biomass': None,
#    'solar': 746.7},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 12, 15, 55, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 5849.0,
#    'gas': 0.04333,
#    'oil': 0,
#    'hydro': 724.7,
#    'wind': 1153.0,
#    'biomass': None,
#    'solar': 769.3},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 12, 16, 0, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 5890.0,
#    'gas': 0.08352,
#    'oil': 0,
#    'hydro': 709.7,
#    'wind': 1114.0,
#    'biomass': None,
#    'solar': 756.4},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 12, 16, 5, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 5980.0,
#    'gas': 0.1338,
#    'oil': 0,
#    'hydro': 760.0,
#    'wind': 1127.0,
#    'biomass': None,
#    'solar': 830.5},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 12, 16, 10, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 5987.0,
#    'gas': 0.00565,
#    'oil': 0,
#    'hydro': 704.1,
#    'wind': 1106.0,
#    'biomass': None,
#    'solar': 821.1},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 12, 16, 15, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 5855.0,
#    'gas': 0.00565,
#    'oil': 0,
#    'hydro': 571.5,
#    'wind': 1092.0,
#    'biomass': None,
#    'solar': 760.6},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 12, 16, 20, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 5829.0,
#    'gas': 0.08352,
#    'oil': 0,
#    'hydro': 383.5,
#    'wind': 1103.0,
#    'biomass': None,
#    'solar': 746.2},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 12, 16, 25, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 5813.0,
#    'gas': 0.1237,
#    'oil': 0,
#    'hydro': 367.1,
#    'wind': 1112.0,
#    'biomass': None,
#    'solar': 637.6},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 12, 16, 30, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 5707.0,
#    'gas': 0.08352,
#    'oil': 0,
#    'hydro': 311.2,
#    'wind': 1119.0,
#    'biomass': None,
#    'solar': 560.1},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 12, 16, 35, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 5926.0,
#    'gas': 0.08352,
#    'oil': 0,
#    'hydro': 595.8,
#    'wind': 1122.0,
#    'biomass': None,
#    'solar': 482.8},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 12, 16, 40, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 5847.0,
#    'gas': 0.08352,
#    'oil': 0,
#    'hydro': 475.0,
#    'wind': 1102.0,
#    'biomass': None,
#    'solar': 464.2},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 12, 16, 45, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 5954.0,
#    'gas': 0.08352,
#    'oil': 0,
#    'hydro': 379.5,
#    'wind': 1094.0,
#    'biomass': None,
#    'solar': 463.2},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 12, 16, 50, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 6119.0,
#    'gas': 0.00565,
#    'oil': 0,
#    'hydro': 673.0,
#    'wind': 1088.0,
#    'biomass': None,
#    'solar': 512.7},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 12, 16, 55, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 6022.0,
#    'gas': 0.08352,
#    'oil': 0,
#    'hydro': 609.0,
#    'wind': 1091.0,
#    'biomass': None,
#    'solar': 435.4},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 12, 17, 0, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 6169.0,
#    'gas': 0.00565,
#    'oil': 0,
#    'hydro': 814.1,
#    'wind': 1068.0,
#    'biomass': None,
#    'solar': 603.3},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 12, 17, 5, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 6295.0,
#    'gas': 0.08352,
#    'oil': 0,
#    'hydro': 1027.0,
#    'wind': 1059.0,
#    'biomass': None,
#    'solar': 620.3},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 12, 17, 10, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 6407.0,
#    'gas': 0.00565,
#    'oil': 0,
#    'hydro': 874.2,
#    'wind': 1060.0,
#    'biomass': None,
#    'solar': 645.1},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 12, 17, 15, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 6570.0,
#    'gas': 0.04333,
#    'oil': 0,
#    'hydro': 884.8,
#    'wind': 1067.0,
#    'biomass': None,
#    'solar': 644.7},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 12, 17, 20, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 6694.0,
#    'gas': 0.00565,
#    'oil': 0,
#    'hydro': 890.5,
#    'wind': 1044.0,
#    'biomass': None,
#    'solar': 664.0},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 12, 17, 25, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 6829.0,
#    'gas': 0.08352,
#    'oil': 0,
#    'hydro': 891.2,
#    'wind': 1032.0,
#    'biomass': None,
#    'solar': 544.4},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 12, 17, 30, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 6935.0,
#    'gas': 0.08352,
#    'oil': 0,
#    'hydro': 882.9,
#    'wind': 1020.0,
#    'biomass': None,
#    'solar': 424.1},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 12, 17, 35, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 7003.0,
#    'gas': 0.00565,
#    'oil': 0,
#    'hydro': 818.9,
#    'wind': 1011.0,
#    'biomass': None,
#    'solar': 367.5},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 12, 17, 40, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 6829.0,
#    'gas': 0.08352,
#    'oil': 0,
#    'hydro': 781.5,
#    'wind': 1016.0,
#    'biomass': None,
#    'solar': 322.1},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 12, 17, 45, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 6785.0,
#    'gas': 0.08352,
#    'oil': 0,
#    'hydro': 723.2,
#    'wind': 1015.0,
#    'biomass': None,
#    'solar': 325.6},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 12, 17, 50, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 6695.0,
#    'gas': 0.00565,
#    'oil': 0,
#    'hydro': 864.2,
#    'wind': 1022.0,
#    'biomass': None,
#    'solar': 236.1},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 12, 17, 55, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 6663.0,
#    'gas': 0.08352,
#    'oil': 0,
#    'hydro': 986.8,
#    'wind': 1044.0,
#    'biomass': None,
#    'solar': 200.6},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 12, 18, 0, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 6718.0,
#    'gas': 0.04333,
#    'oil': 0,
#    'hydro': 997.6,
#    'wind': 1068.0,
#    'biomass': None,
#    'solar': 84.94},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 12, 18, 5, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 6674.0,
#    'gas': 0.08352,
#    'oil': 0,
#    'hydro': 987.0,
#    'wind': 1079.0,
#    'biomass': None,
#    'solar': 81.69},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 12, 18, 10, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 6671.0,
#    'gas': 0.08352,
#    'oil': 0,
#    'hydro': 960.8,
#    'wind': 1090.0,
#    'biomass': None,
#    'solar': 36.8},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 12, 18, 15, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 6666.0,
#    'gas': 0.1237,
#    'oil': 0,
#    'hydro': 973.6,
#    'wind': 1109.0,
#    'biomass': None,
#    'solar': 45.97},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 12, 18, 20, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 6722.0,
#    'gas': 0.08352,
#    'oil': 0,
#    'hydro': 1046.0,
#    'wind': 1098.0,
#    'biomass': None,
#    'solar': 35.01},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 12, 18, 25, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 6771.0,
#    'gas': 0.1237,
#    'oil': 0,
#    'hydro': 987.8,
#    'wind': 1107.0,
#    'biomass': None,
#    'solar': 17.84},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 12, 18, 30, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 6849.0,
#    'gas': 0.1237,
#    'oil': 0,
#    'hydro': 968.2,
#    'wind': 1103.0,
#    'biomass': None,
#    'solar': 6.521},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 12, 18, 35, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 6838.0,
#    'gas': 0.1237,
#    'oil': 0,
#    'hydro': 983.4,
#    'wind': 1100.0,
#    'biomass': None,
#    'solar': 2.253},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 12, 18, 40, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 6765.0,
#    'gas': 0.1237,
#    'oil': 0,
#    'hydro': 1057.0,
#    'wind': 1086.0,
#    'biomass': None,
#    'solar': 0.1939},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 12, 18, 45, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 6777.0,
#    'gas': 0.08352,
#    'oil': 0,
#    'hydro': 992.6,
#    'wind': 1075.0,
#    'biomass': None,
#    'solar': 0.067},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 12, 18, 50, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 6788.0,
#    'gas': 0.1438,
#    'oil': 0,
#    'hydro': 889.6,
#    'wind': 1063.0,
#    'biomass': None,
#    'solar': 0.067},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 12, 18, 55, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 6798.0,
#    'gas': 0.1237,
#    'oil': 0,
#    'hydro': 886.2,
#    'wind': 1055.0,
#    'biomass': None,
#    'solar': 0.067},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 12, 19, 0, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 6792.0,
#    'gas': 0.04333,
#    'oil': 0,
#    'hydro': 882.0,
#    'wind': 1061.0,
#    'biomass': None,
#    'solar': 0.067},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 12, 19, 5, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 6790.0,
#    'gas': 0.1237,
#    'oil': 0,
#    'hydro': 881.7,
#    'wind': 1069.0,
#    'biomass': None,
#    'solar': 0.067},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 12, 19, 10, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 6637.0,
#    'gas': 0.1438,
#    'oil': 0,
#    'hydro': 965.3,
#    'wind': 1079.0,
#    'biomass': None,
#    'solar': 0.067},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 12, 19, 15, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 6593.0,
#    'gas': 0.04333,
#    'oil': 0,
#    'hydro': 998.6,
#    'wind': 1088.0,
#    'biomass': None,
#    'solar': 0.064},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 12, 19, 20, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 6528.0,
#    'gas': 0.08352,
#    'oil': 0,
#    'hydro': 993.8,
#    'wind': 1104.0,
#    'biomass': None,
#    'solar': 0.064},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 12, 19, 25, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 6491.0,
#    'gas': 0.1438,
#    'oil': 0,
#    'hydro': 994.5,
#    'wind': 1100.0,
#    'biomass': None,
#    'solar': 0.064},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 12, 19, 30, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 6453.0,
#    'gas': 0.1237,
#    'oil': 0,
#    'hydro': 847.1,
#    'wind': 1118.0,
#    'biomass': None,
#    'solar': 0.064},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 12, 19, 35, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 6408.0,
#    'gas': 0.1237,
#    'oil': 0,
#    'hydro': 804.5,
#    'wind': 1143.0,
#    'biomass': None,
#    'solar': 0.064},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 12, 19, 40, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 6288.0,
#    'gas': 0.1438,
#    'oil': 0,
#    'hydro': 805.1,
#    'wind': 1148.0,
#    'biomass': None,
#    'solar': 0.064},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 12, 19, 45, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 6301.0,
#    'gas': 0.1438,
#    'oil': 0,
#    'hydro': 634.2,
#    'wind': 1148.0,
#    'biomass': None,
#    'solar': 0.064},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 12, 19, 50, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 6248.0,
#    'gas': 0.08352,
#    'oil': 0,
#    'hydro': 642.3,
#    'wind': 1162.0,
#    'biomass': None,
#    'solar': 0.064},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 12, 19, 55, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 6163.0,
#    'gas': 0.1237,
#    'oil': 0,
#    'hydro': 611.9,
#    'wind': 1178.0,
#    'biomass': None,
#    'solar': 0.064},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 12, 20, 0, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 6132.0,
#    'gas': 0.1438,
#    'oil': 0,
#    'hydro': 625.8,
#    'wind': 1184.0,
#    'biomass': None,
#    'solar': 0.063},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 12, 20, 5, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 6093.0,
#    'gas': 0.08352,
#    'oil': 0,
#    'hydro': 650.0,
#    'wind': 1197.0,
#    'biomass': None,
#    'solar': 0.063},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 12, 20, 10, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 6075.0,
#    'gas': 0.1237,
#    'oil': 0,
#    'hydro': 602.4,
#    'wind': 1206.0,
#    'biomass': None,
#    'solar': 0.063},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 12, 20, 15, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 5936.0,
#    'gas': 0.1539,
#    'oil': 0,
#    'hydro': 598.9,
#    'wind': 1203.0,
#    'biomass': None,
#    'solar': 0.063},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 12, 20, 20, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 5926.0,
#    'gas': 0.08352,
#    'oil': 0,
#    'hydro': 628.5,
#    'wind': 1207.0,
#    'biomass': None,
#    'solar': 0.063},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
# ...
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 13, 10, 30, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 4638.0,
#    'gas': 0.1237,
#    'oil': 0,
#    'hydro': 472.5,
#    'wind': 1154.0,
#    'biomass': None,
#    'solar': 810.8},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 13, 10, 35, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 4716.0,
#    'gas': 0.1237,
#    'oil': 0,
#    'hydro': 449.7,
#    'wind': 1128.0,
#    'biomass': None,
#    'solar': 819.1},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 13, 10, 40, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 4714.0,
#    'gas': 0.08352,
#    'oil': 0,
#    'hydro': 459.4,
#    'wind': 1121.0,
#    'biomass': None,
#    'solar': 811.6},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 13, 10, 45, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 4574.0,
#    'gas': 0.04333,
#    'oil': 0,
#    'hydro': 329.8,
#    'wind': 1100.0,
#    'biomass': None,
#    'solar': 808.8},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 13, 10, 50, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 4525.0,
#    'gas': 0.1237,
#    'oil': 0,
#    'hydro': 329.9,
#    'wind': 1098.0,
#    'biomass': None,
#    'solar': 795.8},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 13, 10, 55, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 4615.0,
#    'gas': 0.08352,
#    'oil': 0,
#    'hydro': 467.2,
#    'wind': 1112.0,
#    'biomass': None,
#    'solar': 803.7},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 13, 11, 0, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 4805.0,
#    'gas': 0.1237,
#    'oil': 0,
#    'hydro': 467.6,
#    'wind': 1109.0,
#    'biomass': None,
#    'solar': 823.0},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 13, 11, 5, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 4685.0,
#    'gas': 0.1438,
#    'oil': 0,
#    'hydro': 455.7,
#    'wind': 1102.0,
#    'biomass': None,
#    'solar': 916.8},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 13, 11, 10, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 4466.0,
#    'gas': 0.08352,
#    'oil': 0,
#    'hydro': 364.6,
#    'wind': 1093.0,
#    'biomass': None,
#    'solar': 771.6},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 13, 11, 15, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 4471.0,
#    'gas': 0.1237,
#    'oil': 0,
#    'hydro': 423.8,
#    'wind': 1067.0,
#    'biomass': None,
#    'solar': 754.1},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 13, 11, 20, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 4583.0,
#    'gas': 0.1338,
#    'oil': 0,
#    'hydro': 464.9,
#    'wind': 1063.0,
#    'biomass': None,
#    'solar': 791.6},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 13, 11, 25, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 4727.0,
#    'gas': 0.08352,
#    'oil': 0,
#    'hydro': 459.0,
#    'wind': 1031.0,
#    'biomass': None,
#    'solar': 907.5},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 13, 11, 30, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 4722.0,
#    'gas': 0.1237,
#    'oil': 0,
#    'hydro': 459.5,
#    'wind': 1064.0,
#    'biomass': None,
#    'solar': 899.9},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 13, 11, 35, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 4541.0,
#    'gas': 0.1438,
#    'oil': 0,
#    'hydro': 313.9,
#    'wind': 1049.0,
#    'biomass': None,
#    'solar': 802.1},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 13, 11, 40, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 4548.0,
#    'gas': 0.04333,
#    'oil': 0,
#    'hydro': 450.2,
#    'wind': 1067.0,
#    'biomass': None,
#    'solar': 743.2},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 13, 11, 45, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 4552.0,
#    'gas': 0.1237,
#    'oil': 0,
#    'hydro': 446.5,
#    'wind': 1060.0,
#    'biomass': None,
#    'solar': 799.6},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 13, 11, 50, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 4463.0,
#    'gas': 0.1237,
#    'oil': 0,
#    'hydro': 434.0,
#    'wind': 1045.0,
#    'biomass': None,
#    'solar': 971.4},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 13, 11, 55, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 4408.0,
#    'gas': 0.04333,
#    'oil': 0,
#    'hydro': 336.1,
#    'wind': 1027.0,
#    'biomass': None,
#    'solar': 959.2},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 13, 12, 0, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 4391.0,
#    'gas': 0.08352,
#    'oil': 0,
#    'hydro': 370.2,
#    'wind': 1036.0,
#    'biomass': None,
#    'solar': 894.0},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 13, 12, 5, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 4425.0,
#    'gas': 0.1237,
#    'oil': 0,
#    'hydro': 427.0,
#    'wind': 969.6,
#    'biomass': None,
#    'solar': 835.2},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 13, 12, 10, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 4570.0,
#    'gas': 0.08352,
#    'oil': 0,
#    'hydro': 469.3,
#    'wind': 999.9,
#    'biomass': None,
#    'solar': 991.2},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 13, 12, 15, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 4726.0,
#    'gas': 0.1237,
#    'oil': 0,
#    'hydro': 443.7,
#    'wind': 994.9,
#    'biomass': None,
#    'solar': 972.4},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 13, 12, 20, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 4797.0,
#    'gas': 0.04333,
#    'oil': 0,
#    'hydro': 449.0,
#    'wind': 997.6,
#    'biomass': None,
#    'solar': 899.3},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 13, 12, 25, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 4850.0,
#    'gas': 0.08352,
#    'oil': 0,
#    'hydro': 437.1,
#    'wind': 972.7,
#    'biomass': None,
#    'solar': 1008.0},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 13, 12, 30, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 4879.0,
#    'gas': 0.1438,
#    'oil': 0,
#    'hydro': 441.6,
#    'wind': 994.6,
#    'biomass': None,
#    'solar': 1042.0},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 13, 12, 35, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 4753.0,
#    'gas': 0.08352,
#    'oil': 0,
#    'hydro': 217.7,
#    'wind': 1002.0,
#    'biomass': None,
#    'solar': 835.2},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 13, 12, 40, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 4660.0,
#    'gas': 0.1237,
#    'oil': 0,
#    'hydro': 207.0,
#    'wind': 982.9,
#    'biomass': None,
#    'solar': 1030.0},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 13, 12, 45, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 4524.0,
#    'gas': 0.1438,
#    'oil': 0,
#    'hydro': 248.6,
#    'wind': 966.4,
#    'biomass': None,
#    'solar': 1070.0},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 13, 12, 50, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 4750.0,
#    'gas': 0.04333,
#    'oil': 0,
#    'hydro': 472.0,
#    'wind': 973.9,
#    'biomass': None,
#    'solar': 1038.0},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'},
#  {'datetime': datetime.datetime(2021, 10, 13, 12, 55, tzinfo=tzoffset(None, 36000)),
#   'production': {'coal': 4487.0,
#    'gas': 0.1237,
#    'oil': 0,
#    'hydro': 364.9,
#    'wind': 923.5,
#    'biomass': None,
#    'solar': 1138.0},
#   'storage': {'battery': None, 'hydro': None},
#   'capacity': {'coal': 11990.0,
#    'gas': 479.0,
#    'oil': 178.0,
#    'hydro': 4208.0,
#    'wind': 2125.69,
#    'biomass': None,
#    'solar': 2747.992,
#    'hydro storage': None,
#    'battery storage': None},
#   'source': 'opennem.org.au',
#   'zoneKey': 'AUS-NSW'}]

# %%
datetime=datetime.datetime(2020, 10, 12, 9, 15, tzinfo=dateutil.tz.tzoffset(None, 36000))

# %%
result_nsw_202010 = fetch_production('AUS-NSW', target_datetime=datetime)
